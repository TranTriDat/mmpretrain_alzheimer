# %%
# %%writefile configs/resnet/resnet50_ISIC_2019.py
_base_ = [
    '../_base_/models/resnet50.py', 
    '../_base_/schedules/imagenet_bs1024_adamw_conformer.py',
    '../_base_/default_runtime.py'
]

pretrained='https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth'

model = dict(
    type='ImageClassifier',
    backbone=dict(
        type='ResNet', 
        style='pytorch',
        init_cfg=dict(
            type='Pretrained',
            checkpoint=pretrained,
            prefix='backbone'
        ),
    ),
    head=dict(
        num_classes=8,
        topk=(1, 8),
    ))

dataset_type = 'CustomDataset'
# dataset_type = 'ImageNet'
data_preprocessor = dict(
     mean=[124.508, 116.050, 106.438],
     std=[58.577, 57.310, 57.437],
     to_rgb=True)

train_pipeline = [
    dict(type='LoadImageFromFile'),     # read image
    dict(type='ResizeEdge', scale=256),  # Scale the short side to 256
    dict(type='RandomResizedCrop', scale=224), # 224x224
    dict(type='RandomFlip', prob=0.5, direction='horizontal'),   # random horizontal flip
    dict(type='PackInputs'),
]
test_pipeline = [
    dict(type='LoadImageFromFile'),     # read image
    dict(type='ResizeEdge', scale=256),  # Scale the short side to 256
    dict(type='CenterCrop', crop_size=224),
    dict(type='PackInputs'),    
]

train_dataloader = dict(
    batch_size=32,
    num_workers=2,
    dataset=dict(
        type=dataset_type,
        data_root='../Dat/Vit/lora',
        data_prefix='ISIC2019_train/Image',
        classes='data/classes_ISIC_2019.txt',
        with_label=True,
        split='train',
        pipeline=train_pipeline
    ),
    sampler=dict(type='DefaultSampler', shuffle=True),
    persistent_workers=True
)

val_dataloader = dict(
    batch_size=32,
    num_workers=2,
    dataset=dict(
        type=dataset_type,
        data_root='../Dat/Vit/lora',
        data_prefix='ISIC2019_train/Image',
        classes='data/classes_ISIC_2019.txt',
        with_label=True,
        split='val',
        pipeline=test_pipeline
    ),
    sampler=dict(type='DefaultSampler', shuffle=False),
    persistent_workers=True
)

test_dataloader = dict(
    batch_size=32,
    num_workers=2,
    dataset=dict(
        type=dataset_type,
        data_root='../Dat/Vit/lora',
        data_prefix='ISIC2019_train/Image',
        classes='data/classes_ISIC_2019.txt',
        with_label=True,
        split='val',
        pipeline=test_pipeline
    ),    
    sampler=dict(type='DefaultSampler', shuffle=False),
    persistent_workers=True
)

val_evaluator = dict(type='Accuracy', topk=(1, 3))
test_evaluator = val_evaluator 

optim_wrapper = dict(
    optimizer=dict(
        type='AdamW',
        # for batch in each gpu is 128, 8 gpu
        # lr = 5e-4 * 128 * 8 / 512 = 0.001
        lr=5e-4 * 128 * 8 / 512,
        weight_decay=0.05,
        eps=1e-8,
        betas=(0.9, 0.999)),
    paramwise_cfg=dict(
        norm_decay_mult=0.0,
        bias_decay_mult=0.0,
        custom_keys={
            '.cls_token': dict(decay_mult=0.0),
        }),
)

# learning policy
param_scheduler = [
    dict(
        type='LinearLR',
        start_factor=1e-3,
        by_epoch=True,
        begin=0,
        end=5,
        convert_to_iter_based=True),
    dict(
        type='CosineAnnealingLR',
        T_max=295,
        eta_min=1e-5,
        by_epoch=True,
        begin=5,
        end=300)
]

train_cfg = dict(by_epoch=True, max_epochs=100, val_interval=1)
val_cfg = dict()
test_cfg = dict()

auto_scale_lr = dict(base_batch_size=128)

default_scope = 'mmpretrain'

# configure default hooks
default_hooks = dict(
    # record the time of every iteration.
    timer=dict(type='IterTimerHook'),

    # print log every 100 iterations.
    logger=dict(type='LoggerHook', interval=100),

    # enable the parameter scheduler.
    param_scheduler=dict(type='ParamSchedulerHook'),

    # save checkpoint per epoch.
    checkpoint=dict(type='CheckpointHook', interval=1),

    # set sampler seed in a distributed environment.
    sampler_seed=dict(type='DistSamplerSeedHook'),

    # validation results visualization, set True to enable it.
    visualization=dict(type='VisualizationHook', enable=False),
)

env_cfg = dict(
    # whether to enable cudnn benchmark
    cudnn_benchmark=False,

    # set multi-process parameters
    mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),

    # set distributed parameters
    dist_cfg=dict(backend='nccl'),
)

# set visualizer
vis_backends = [dict(type='LocalVisBackend')]  # use local HDD backend
visualizer = dict(type='UniversalVisualizer', vis_backends=vis_backends, name='visualizer')

# set log level
log_level = 'INFO'

# load from which checkpoint
load_from = None

# whether to resume training from the loaded checkpoint
resume = False
# Out:
# Writing configs/resnet/resnet50_ISIC_2019.py

# %%
# !python ./tools/train.py \
    configs/resnet/resnet50_ISIC_2019.py \
    --work-dir work_dirs/ISIC/2019/Resnet50 \
    # --auto-scale-lr
# Out:
# configs/resnet/resnet50_ISIC_2019.py
# 12/28 21:43:20 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.18 (default, Sep 11 2023, 13:40:15) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 452479572
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: /usr/local/cuda-11.4
#     NVCC: Cuda compilation tools, release 11.4, V11.4.100
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.10.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.2
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.11.2
#     OpenCV: 4.8.1
#     MMEngine: 0.9.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 452479572
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 12/28 21:43:20 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=128)
# data_preprocessor = dict(
#     mean=[
#         124.508,
#         116.05,
#         106.438,
#     ],
#     std=[
#         58.577,
#         57.31,
#         57.437,
#     ],
#     to_rgb=True)
# dataset_type = 'CustomDataset'
# default_hooks = dict(
#     checkpoint=dict(interval=1, type='CheckpointHook'),
#     logger=dict(interval=100, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(enable=False, type='VisualizationHook'))
# default_scope = 'mmpretrain'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# model = dict(
#     backbone=dict(
#         depth=50,
#         init_cfg=dict(
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth',
#             prefix='backbone',
#             type='Pretrained'),
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch',
#         type='ResNet'),
#     head=dict(
#         in_channels=2048,
#         loss=dict(loss_weight=1.0, type='CrossEntropyLoss'),
#         num_classes=8,
#         topk=(
#             1,
#             8,
#         ),
#         type='LinearClsHead'),
#     neck=dict(type='GlobalAveragePooling'),
#     type='ImageClassifier')
# optim_wrapper = dict(
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ),
#         eps=1e-08,
#         lr=0.001,
#         type='AdamW',
#         weight_decay=0.05),
#     paramwise_cfg=dict(
#         bias_decay_mult=0.0,
#         custom_keys=dict({'.cls_token': dict(decay_mult=0.0)}),
#         norm_decay_mult=0.0))
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=5,
#         start_factor=0.001,
#         type='LinearLR'),
#     dict(
#         T_max=295,
#         begin=5,
#         by_epoch=True,
#         end=300,
#         eta_min=1e-05,
#         type='CosineAnnealingLR'),
# ]
# pretrained = 'https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth'
# randomness = dict(deterministic=False, seed=None)
# resume = False
# test_cfg = dict()
# test_dataloader = dict(
#     batch_size=32,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         classes='data/classes_ISIC_2019.txt',
#         data_prefix='ISIC2019_train/Image',
#         data_root='../Dat/Vit/lora',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(scale=256, type='ResizeEdge'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(type='PackInputs'),
#         ],
#         split='val',
#         type='CustomDataset',
#         with_label=True),
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     topk=(
#         1,
#         3,
#     ), type='Accuracy')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(scale=256, type='ResizeEdge'),
#     dict(crop_size=224, type='CenterCrop'),
#     dict(type='PackInputs'),
# ]
# train_cfg = dict(by_epoch=True, max_epochs=100, val_interval=1)
# train_dataloader = dict(
#     batch_size=32,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         classes='data/classes_ISIC_2019.txt',
#         data_prefix='ISIC2019_train/Image',
#         data_root='../Dat/Vit/lora',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(scale=256, type='ResizeEdge'),
#             dict(scale=224, type='RandomResizedCrop'),
#             dict(direction='horizontal', prob=0.5, type='RandomFlip'),
#             dict(type='PackInputs'),
#         ],
#         split='train',
#         type='CustomDataset',
#         with_label=True),
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(scale=256, type='ResizeEdge'),
#     dict(scale=224, type='RandomResizedCrop'),
#     dict(direction='horizontal', prob=0.5, type='RandomFlip'),
#     dict(type='PackInputs'),
# ]
# val_cfg = dict()
# val_dataloader = dict(
#     batch_size=32,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         classes='data/classes_ISIC_2019.txt',
#         data_prefix='ISIC2019_train/Image',
#         data_root='../Dat/Vit/lora',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(scale=256, type='ResizeEdge'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(type='PackInputs'),
#         ],
#         split='val',
#         type='CustomDataset',
#         with_label=True),
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     topk=(
#         1,
#         3,
#     ), type='Accuracy')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='UniversalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = 'work_dirs/ISIC/2019/Resnet50'
#
# 12/28 21:43:42 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 12/28 21:43:42 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.0.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.0.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.0.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.0.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.0.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.0.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.0.downsample.1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.0.downsample.1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.1.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.1.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.1.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.1.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.1.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.1.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.2.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.2.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.2.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.2.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.2.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer1.2.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.0.downsample.1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.0.downsample.1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.2.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.2.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.2.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.2.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.2.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.2.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.3.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.3.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.3.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.3.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.3.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer2.3.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.0.downsample.1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.0.downsample.1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.2.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.2.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.2.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.2.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.2.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.2.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.3.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.3.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.3.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.3.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.3.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.3.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.4.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.4.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.4.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.4.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.4.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.4.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.5.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.5.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.5.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.5.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.5.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer3.5.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.0.downsample.1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.0.downsample.1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.2.bn1.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.2.bn1.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.2.bn2.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.2.bn2.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.2.bn3.weight:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- backbone.layer4.2.bn3.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - paramwise_options -- head.fc.bias:weight_decay=0.0
# 12/28 21:43:43 - mmengine - INFO - load backbone in model from: https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth
# Downloading: "https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth" to /home/user/.cache/torch/hub/checkpoints/resnet50_8xb32_in1k_20210831-ea4938fc.pth
# 100%|██████████████████████████████████████| 97.8M/97.8M [00:21<00:00, 4.68MB/s]
# 12/28 21:44:08 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 12/28 21:44:08 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 12/28 21:44:08 - mmengine - INFO - Checkpoints will be saved to /home/user/mmpretrain/work_dirs/ISIC/2019/Resnet50.
# 12/28 21:44:44 - mmengine - INFO - Epoch(train)   [1][100/792]  base_lr: 2.5981e-05 lr: 2.5981e-05  eta: 7:59:05  time: 0.2786  data_time: 0.2000  memory: 3057  loss: 1.0932
# 12/28 21:45:14 - mmengine - INFO - Epoch(train)   [1][200/792]  base_lr: 5.1215e-05 lr: 5.1215e-05  eta: 7:13:36  time: 0.2931  data_time: 0.2144  memory: 3057  loss: 0.9373
# 12/28 21:45:45 - mmengine - INFO - Epoch(train)   [1][300/792]  base_lr: 7.6449e-05 lr: 7.6449e-05  eta: 7:02:41  time: 0.3051  data_time: 0.2255  memory: 3057  loss: 0.9323
# 12/28 21:46:16 - mmengine - INFO - Epoch(train)   [1][400/792]  base_lr: 1.0168e-04 lr: 1.0168e-04  eta: 7:00:24  time: 0.3066  data_time: 0.2270  memory: 3057  loss: 1.0229
# 12/28 21:46:51 - mmengine - INFO - Epoch(train)   [1][500/792]  base_lr: 1.2692e-04 lr: 1.2692e-04  eta: 7:06:31  time: 0.3838  data_time: 0.3046  memory: 3057  loss: 0.9641
# 12/28 21:47:28 - mmengine - INFO - Epoch(train)   [1][600/792]  base_lr: 1.5215e-04 lr: 1.5215e-04  eta: 7:16:33  time: 0.3775  data_time: 0.2968  memory: 3057  loss: 0.9075
# 12/28 21:48:08 - mmengine - INFO - Epoch(train)   [1][700/792]  base_lr: 1.7738e-04 lr: 1.7738e-04  eta: 7:28:58  time: 0.4213  data_time: 0.3404  memory: 3057  loss: 1.0456
# 12/28 21:48:47 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 21:48:47 - mmengine - INFO - Saving checkpoint at 1 epochs
# 12/28 21:49:25 - mmengine - INFO - Epoch(val)   [1][100/792]    eta: 0:04:12  time: 0.5565  data_time: 0.5301  memory: 3057
# 12/28 21:49:55 - mmengine - INFO - Epoch(val)   [1][200/792]    eta: 0:03:19  time: 0.3547  data_time: 0.3285  memory: 704
# 12/28 21:50:25 - mmengine - INFO - Epoch(val)   [1][300/792]    eta: 0:02:38  time: 0.3835  data_time: 0.3573  memory: 704
# 12/28 21:50:59 - mmengine - INFO - Epoch(val)   [1][400/792]    eta: 0:02:07  time: 0.2339  data_time: 0.2077  memory: 704
# 12/28 21:51:19 - mmengine - INFO - Epoch(val)   [1][500/792]    eta: 0:01:28  time: 0.1949  data_time: 0.1686  memory: 704
# 12/28 21:51:38 - mmengine - INFO - Epoch(val)   [1][600/792]    eta: 0:00:54  time: 0.1928  data_time: 0.1666  memory: 704
# 12/28 21:52:14 - mmengine - INFO - Epoch(val)   [1][700/792]    eta: 0:00:27  time: 0.4180  data_time: 0.3918  memory: 704
# 12/28 21:52:52 - mmengine - INFO - Epoch(val) [1][792/792]    accuracy/top1: 61.2925  accuracy/top3: 92.3651  data_time: 0.2817  time: 0.3079
# 12/28 21:53:20 - mmengine - INFO - Epoch(train)   [2][100/792]  base_lr: 2.2583e-04 lr: 2.2583e-04  eta: 7:29:17  time: 0.2708  data_time: 0.1914  memory: 3057  loss: 0.9646
# 12/28 21:53:49 - mmengine - INFO - Epoch(train)   [2][200/792]  base_lr: 2.5107e-04 lr: 2.5107e-04  eta: 7:20:31  time: 0.2841  data_time: 0.2046  memory: 3057  loss: 0.9603
# 12/28 21:53:51 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 21:54:17 - mmengine - INFO - Epoch(train)   [2][300/792]  base_lr: 2.7630e-04 lr: 2.7630e-04  eta: 7:13:34  time: 0.2898  data_time: 0.2106  memory: 3057  loss: 0.8619
# 12/28 21:54:48 - mmengine - INFO - Epoch(train)   [2][400/792]  base_lr: 3.0153e-04 lr: 3.0153e-04  eta: 7:10:15  time: 0.3367  data_time: 0.2572  memory: 3057  loss: 0.8597
# 12/28 21:55:20 - mmengine - INFO - Epoch(train)   [2][500/792]  base_lr: 3.2677e-04 lr: 3.2677e-04  eta: 7:08:19  time: 0.2997  data_time: 0.2201  memory: 3057  loss: 0.9018
# 12/28 21:55:56 - mmengine - INFO - Epoch(train)   [2][600/792]  base_lr: 3.5200e-04 lr: 3.5200e-04  eta: 7:11:21  time: 0.3823  data_time: 0.3032  memory: 3057  loss: 0.8505
# 12/28 21:56:38 - mmengine - INFO - Epoch(train)   [2][700/792]  base_lr: 3.7723e-04 lr: 3.7723e-04  eta: 7:17:56  time: 0.4057  data_time: 0.3264  memory: 3057  loss: 0.8777
# 12/28 21:57:24 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 21:57:24 - mmengine - INFO - Saving checkpoint at 2 epochs
# 12/28 21:58:05 - mmengine - INFO - Epoch(val)   [2][100/792]    eta: 0:04:29  time: 0.6906  data_time: 0.6643  memory: 3057
# 12/28 21:58:37 - mmengine - INFO - Epoch(val)   [2][200/792]    eta: 0:03:30  time: 0.4026  data_time: 0.3765  memory: 704
# 12/28 21:59:08 - mmengine - INFO - Epoch(val)   [2][300/792]    eta: 0:02:48  time: 0.4321  data_time: 0.4060  memory: 704
# 12/28 21:59:43 - mmengine - INFO - Epoch(val)   [2][400/792]    eta: 0:02:14  time: 0.2542  data_time: 0.2281  memory: 704
# 12/28 22:00:15 - mmengine - INFO - Epoch(val)   [2][500/792]    eta: 0:01:38  time: 0.4963  data_time: 0.4702  memory: 704
# 12/28 22:00:47 - mmengine - INFO - Epoch(val)   [2][600/792]    eta: 0:01:04  time: 0.1837  data_time: 0.1576  memory: 704
# 12/28 22:01:22 - mmengine - INFO - Epoch(val)   [2][700/792]    eta: 0:00:31  time: 0.4335  data_time: 0.4073  memory: 704
# 12/28 22:01:59 - mmengine - INFO - Epoch(val) [2][792/792]    accuracy/top1: 68.3826  accuracy/top3: 93.6481  data_time: 0.3185  time: 0.3447
# 12/28 22:02:25 - mmengine - INFO - Epoch(train)   [3][100/792]  base_lr: 4.2568e-04 lr: 4.2568e-04  eta: 7:23:01  time: 0.2752  data_time: 0.1961  memory: 3057  loss: 0.9634
# 12/28 22:02:53 - mmengine - INFO - Epoch(train)   [3][200/792]  base_lr: 4.5092e-04 lr: 4.5092e-04  eta: 7:17:27  time: 0.3506  data_time: 0.2716  memory: 3057  loss: 0.8537
# 12/28 22:03:26 - mmengine - INFO - Epoch(train)   [3][300/792]  base_lr: 4.7615e-04 lr: 4.7615e-04  eta: 7:16:22  time: 0.2811  data_time: 0.2017  memory: 3057  loss: 0.8991
# 12/28 22:03:55 - mmengine - INFO - Epoch(train)   [3][400/792]  base_lr: 5.0138e-04 lr: 5.0138e-04  eta: 7:12:28  time: 0.3049  data_time: 0.2257  memory: 3057  loss: 0.9087
# 12/28 22:03:59 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:04:26 - mmengine - INFO - Epoch(train)   [3][500/792]  base_lr: 5.2662e-04 lr: 5.2662e-04  eta: 7:10:30  time: 0.3354  data_time: 0.2563  memory: 3057  loss: 0.9297
# 12/28 22:05:01 - mmengine - INFO - Epoch(train)   [3][600/792]  base_lr: 5.5185e-04 lr: 5.5185e-04  eta: 7:10:56  time: 0.3770  data_time: 0.2978  memory: 3057  loss: 0.8697
# 12/28 22:05:41 - mmengine - INFO - Epoch(train)   [3][700/792]  base_lr: 5.7708e-04 lr: 5.7708e-04  eta: 7:13:59  time: 0.4014  data_time: 0.3223  memory: 3057  loss: 0.9015
# 12/28 22:06:18 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:06:18 - mmengine - INFO - Saving checkpoint at 3 epochs
# 12/28 22:06:57 - mmengine - INFO - Epoch(val)   [3][100/792]    eta: 0:04:23  time: 0.5891  data_time: 0.5629  memory: 3057
# 12/28 22:07:29 - mmengine - INFO - Epoch(val)   [3][200/792]    eta: 0:03:26  time: 0.3895  data_time: 0.3634  memory: 704
# 12/28 22:07:59 - mmengine - INFO - Epoch(val)   [3][300/792]    eta: 0:02:44  time: 0.3861  data_time: 0.3600  memory: 704
# 12/28 22:08:32 - mmengine - INFO - Epoch(val)   [3][400/792]    eta: 0:02:09  time: 0.2261  data_time: 0.1998  memory: 704
# 12/28 22:08:51 - mmengine - INFO - Epoch(val)   [3][500/792]    eta: 0:01:28  time: 0.1759  data_time: 0.1498  memory: 704
# 12/28 22:09:09 - mmengine - INFO - Epoch(val)   [3][600/792]    eta: 0:00:54  time: 0.1894  data_time: 0.1633  memory: 704
# 12/28 22:09:43 - mmengine - INFO - Epoch(val)   [3][700/792]    eta: 0:00:26  time: 0.4226  data_time: 0.3964  memory: 704
# 12/28 22:10:20 - mmengine - INFO - Epoch(val) [3][792/792]    accuracy/top1: 68.5405  accuracy/top3: 93.4902  data_time: 0.2773  time: 0.3034
# 12/28 22:10:48 - mmengine - INFO - Epoch(train)   [4][100/792]  base_lr: 6.2553e-04 lr: 6.2553e-04  eta: 7:12:38  time: 0.3158  data_time: 0.2367  memory: 3057  loss: 0.8900
# 12/28 22:11:14 - mmengine - INFO - Epoch(train)   [4][200/792]  base_lr: 6.5077e-04 lr: 6.5077e-04  eta: 7:08:27  time: 0.2760  data_time: 0.1968  memory: 3057  loss: 1.0040
# 12/28 22:11:41 - mmengine - INFO - Epoch(train)   [4][300/792]  base_lr: 6.7600e-04 lr: 6.7600e-04  eta: 7:04:32  time: 0.2533  data_time: 0.1738  memory: 3057  loss: 1.1200
# 12/28 22:12:08 - mmengine - INFO - Epoch(train)   [4][400/792]  base_lr: 7.0123e-04 lr: 7.0123e-04  eta: 7:01:15  time: 0.2824  data_time: 0.2033  memory: 3057  loss: 0.9239
# 12/28 22:12:38 - mmengine - INFO - Epoch(train)   [4][500/792]  base_lr: 7.2647e-04 lr: 7.2647e-04  eta: 6:59:14  time: 0.2917  data_time: 0.2123  memory: 3057  loss: 0.9355
# 12/28 22:13:11 - mmengine - INFO - Epoch(train)   [4][600/792]  base_lr: 7.5170e-04 lr: 7.5170e-04  eta: 6:58:50  time: 0.3586  data_time: 0.2795  memory: 3057  loss: 0.9002
# 12/28 22:13:20 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:13:51 - mmengine - INFO - Epoch(train)   [4][700/792]  base_lr: 7.7693e-04 lr: 7.7693e-04  eta: 7:01:11  time: 0.4889  data_time: 0.4102  memory: 3057  loss: 0.9269
# 12/28 22:14:30 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:14:30 - mmengine - INFO - Saving checkpoint at 4 epochs
# 12/28 22:15:06 - mmengine - INFO - Epoch(val)   [4][100/792]    eta: 0:03:55  time: 0.3807  data_time: 0.3546  memory: 3057
# 12/28 22:15:40 - mmengine - INFO - Epoch(val)   [4][200/792]    eta: 0:03:22  time: 0.3890  data_time: 0.3629  memory: 704
# 12/28 22:16:11 - mmengine - INFO - Epoch(val)   [4][300/792]    eta: 0:02:42  time: 0.3781  data_time: 0.3520  memory: 704
# 12/28 22:16:43 - mmengine - INFO - Epoch(val)   [4][400/792]    eta: 0:02:08  time: 0.2306  data_time: 0.2045  memory: 704
# 12/28 22:17:03 - mmengine - INFO - Epoch(val)   [4][500/792]    eta: 0:01:28  time: 0.2007  data_time: 0.1746  memory: 704
# 12/28 22:17:26 - mmengine - INFO - Epoch(val)   [4][600/792]    eta: 0:00:55  time: 0.3865  data_time: 0.3605  memory: 704
# 12/28 22:18:02 - mmengine - INFO - Epoch(val)   [4][700/792]    eta: 0:00:27  time: 0.4180  data_time: 0.3919  memory: 704
# 12/28 22:18:39 - mmengine - INFO - Epoch(val) [4][792/792]    accuracy/top1: 68.5366  accuracy/top3: 93.1625  data_time: 0.2858  time: 0.3119
# 12/28 22:19:05 - mmengine - INFO - Epoch(train)   [5][100/792]  base_lr: 8.2538e-04 lr: 8.2538e-04  eta: 7:00:17  time: 0.2455  data_time: 0.1669  memory: 3057  loss: 0.8748
# 12/28 22:19:31 - mmengine - INFO - Epoch(train)   [5][200/792]  base_lr: 8.5062e-04 lr: 8.5062e-04  eta: 6:57:04  time: 0.2663  data_time: 0.1872  memory: 3057  loss: 0.9616
# 12/28 22:19:57 - mmengine - INFO - Epoch(train)   [5][300/792]  base_lr: 8.7585e-04 lr: 8.7585e-04  eta: 6:54:07  time: 0.2553  data_time: 0.1766  memory: 3057  loss: 0.9126
# 12/28 22:20:25 - mmengine - INFO - Epoch(train)   [5][400/792]  base_lr: 9.0108e-04 lr: 9.0108e-04  eta: 6:51:44  time: 0.2840  data_time: 0.2044  memory: 3057  loss: 0.9928
# 12/28 22:20:54 - mmengine - INFO - Epoch(train)   [5][500/792]  base_lr: 9.2632e-04 lr: 9.2632e-04  eta: 6:50:01  time: 0.2926  data_time: 0.2135  memory: 3057  loss: 0.8811
# 12/28 22:21:26 - mmengine - INFO - Epoch(train)   [5][600/792]  base_lr: 9.5155e-04 lr: 9.5155e-04  eta: 6:49:22  time: 0.3392  data_time: 0.2600  memory: 3057  loss: 1.0118
# 12/28 22:22:04 - mmengine - INFO - Epoch(train)   [5][700/792]  base_lr: 9.7679e-04 lr: 9.7679e-04  eta: 6:50:36  time: 0.4180  data_time: 0.3390  memory: 3057  loss: 0.9295
# 12/28 22:22:40 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:22:40 - mmengine - INFO - Saving checkpoint at 5 epochs
# 12/28 22:23:16 - mmengine - INFO - Epoch(val)   [5][100/792]    eta: 0:03:54  time: 0.3661  data_time: 0.3399  memory: 3057
# 12/28 22:23:50 - mmengine - INFO - Epoch(val)   [5][200/792]    eta: 0:03:20  time: 0.3809  data_time: 0.3548  memory: 704
# 12/28 22:24:20 - mmengine - INFO - Epoch(val)   [5][300/792]    eta: 0:02:41  time: 0.3935  data_time: 0.3674  memory: 704
# 12/28 22:24:52 - mmengine - INFO - Epoch(val)   [5][400/792]    eta: 0:02:07  time: 0.2392  data_time: 0.2130  memory: 704
# 12/28 22:25:12 - mmengine - INFO - Epoch(val)   [5][500/792]    eta: 0:01:27  time: 0.1904  data_time: 0.1643  memory: 704
# 12/28 22:25:30 - mmengine - INFO - Epoch(val)   [5][600/792]    eta: 0:00:53  time: 0.1753  data_time: 0.1493  memory: 704
# 12/28 22:26:03 - mmengine - INFO - Epoch(val)   [5][700/792]    eta: 0:00:26  time: 0.3976  data_time: 0.3716  memory: 704
# 12/28 22:26:39 - mmengine - INFO - Epoch(val) [5][792/792]    accuracy/top1: 63.2190  accuracy/top3: 92.1440  data_time: 0.2724  time: 0.2984
# 12/28 22:26:49 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:27:04 - mmengine - INFO - Epoch(train)   [6][100/792]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 6:49:08  time: 0.2544  data_time: 0.1752  memory: 3057  loss: 0.9670
# 12/28 22:27:30 - mmengine - INFO - Epoch(train)   [6][200/792]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 6:46:31  time: 0.2625  data_time: 0.1833  memory: 3057  loss: 0.8624
# 12/28 22:27:56 - mmengine - INFO - Epoch(train)   [6][300/792]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 6:44:04  time: 0.2620  data_time: 0.1826  memory: 3057  loss: 0.8903
# 12/28 22:28:32 - mmengine - INFO - Epoch(train)   [6][400/792]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 6:44:34  time: 0.9426  data_time: 0.8623  memory: 3057  loss: 0.9122
# 12/28 22:29:22 - mmengine - INFO - Epoch(train)   [6][500/792]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 6:48:53  time: 0.4697  data_time: 0.3907  memory: 3057  loss: 0.8949
# 12/28 22:30:13 - mmengine - INFO - Epoch(train)   [6][600/792]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 6:53:17  time: 0.3549  data_time: 0.2756  memory: 3057  loss: 0.9399
# 12/28 22:30:52 - mmengine - INFO - Epoch(train)   [6][700/792]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 6:54:23  time: 0.4192  data_time: 0.3398  memory: 3057  loss: 0.8933
# 12/28 22:31:32 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:31:32 - mmengine - INFO - Saving checkpoint at 6 epochs
# 12/28 22:32:11 - mmengine - INFO - Epoch(val)   [6][100/792]    eta: 0:04:23  time: 0.3717  data_time: 0.3456  memory: 3057
# 12/28 22:32:43 - mmengine - INFO - Epoch(val)   [6][200/792]    eta: 0:03:25  time: 0.3988  data_time: 0.3726  memory: 704
# 12/28 22:33:14 - mmengine - INFO - Epoch(val)   [6][300/792]    eta: 0:02:45  time: 0.3941  data_time: 0.3680  memory: 704
# 12/28 22:33:49 - mmengine - INFO - Epoch(val)   [6][400/792]    eta: 0:02:13  time: 0.3093  data_time: 0.2831  memory: 704
# 12/28 22:34:10 - mmengine - INFO - Epoch(val)   [6][500/792]    eta: 0:01:31  time: 0.1674  data_time: 0.1413  memory: 704
# 12/28 22:34:28 - mmengine - INFO - Epoch(val)   [6][600/792]    eta: 0:00:55  time: 0.1740  data_time: 0.1479  memory: 704
# 12/28 22:35:03 - mmengine - INFO - Epoch(val)   [6][700/792]    eta: 0:00:27  time: 0.4334  data_time: 0.4072  memory: 704
# 12/28 22:35:42 - mmengine - INFO - Epoch(val) [6][792/792]    accuracy/top1: 69.9854  accuracy/top3: 92.8033  data_time: 0.2867  time: 0.3129
# 12/28 22:36:08 - mmengine - INFO - Epoch(train)   [7][100/792]  base_lr: 9.9997e-04 lr: 9.9997e-04  eta: 6:53:54  time: 0.2694  data_time: 0.1897  memory: 3057  loss: 0.8790
# 12/28 22:36:35 - mmengine - INFO - Epoch(train)   [7][200/792]  base_lr: 9.9997e-04 lr: 9.9997e-04  eta: 6:51:37  time: 0.2612  data_time: 0.1823  memory: 3057  loss: 1.0431
# 12/28 22:36:47 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:37:02 - mmengine - INFO - Epoch(train)   [7][300/792]  base_lr: 9.9997e-04 lr: 9.9997e-04  eta: 6:49:37  time: 0.2840  data_time: 0.2043  memory: 3057  loss: 0.8864
# 12/28 22:37:30 - mmengine - INFO - Epoch(train)   [7][400/792]  base_lr: 9.9997e-04 lr: 9.9997e-04  eta: 6:47:52  time: 0.2816  data_time: 0.2022  memory: 3057  loss: 0.9895
# 12/28 22:38:00 - mmengine - INFO - Epoch(train)   [7][500/792]  base_lr: 9.9997e-04 lr: 9.9997e-04  eta: 6:46:33  time: 0.3124  data_time: 0.2327  memory: 3057  loss: 0.8856
# 12/28 22:38:33 - mmengine - INFO - Epoch(train)   [7][600/792]  base_lr: 9.9997e-04 lr: 9.9997e-04  eta: 6:46:02  time: 0.3583  data_time: 0.2787  memory: 3057  loss: 0.8596
# 12/28 22:39:16 - mmengine - INFO - Epoch(train)   [7][700/792]  base_lr: 9.9997e-04 lr: 9.9997e-04  eta: 6:47:42  time: 0.4910  data_time: 0.4116  memory: 3057  loss: 0.7748
# 12/28 22:39:54 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:39:54 - mmengine - INFO - Saving checkpoint at 7 epochs
# 12/28 22:40:34 - mmengine - INFO - Epoch(val)   [7][100/792]    eta: 0:04:23  time: 0.3823  data_time: 0.3562  memory: 3057
# 12/28 22:41:06 - mmengine - INFO - Epoch(val)   [7][200/792]    eta: 0:03:27  time: 0.4362  data_time: 0.4099  memory: 704
# 12/28 22:41:38 - mmengine - INFO - Epoch(val)   [7][300/792]    eta: 0:02:47  time: 0.4286  data_time: 0.4024  memory: 704
# 12/28 22:42:13 - mmengine - INFO - Epoch(val)   [7][400/792]    eta: 0:02:14  time: 0.2318  data_time: 0.2057  memory: 704
# 12/28 22:42:32 - mmengine - INFO - Epoch(val)   [7][500/792]    eta: 0:01:31  time: 0.1777  data_time: 0.1514  memory: 704
# 12/28 22:42:51 - mmengine - INFO - Epoch(val)   [7][600/792]    eta: 0:00:56  time: 0.1758  data_time: 0.1496  memory: 704
# 12/28 22:43:26 - mmengine - INFO - Epoch(val)   [7][700/792]    eta: 0:00:27  time: 0.4472  data_time: 0.4208  memory: 704
# 12/28 22:44:06 - mmengine - INFO - Epoch(val) [7][792/792]    accuracy/top1: 69.7762  accuracy/top3: 92.5309  data_time: 0.2890  time: 0.3152
# 12/28 22:44:33 - mmengine - INFO - Epoch(train)   [8][100/792]  base_lr: 9.9989e-04 lr: 9.9989e-04  eta: 6:46:55  time: 0.2686  data_time: 0.1893  memory: 3057  loss: 0.8929
# 12/28 22:44:59 - mmengine - INFO - Epoch(train)   [8][200/792]  base_lr: 9.9989e-04 lr: 9.9989e-04  eta: 6:44:57  time: 0.2707  data_time: 0.1913  memory: 3057  loss: 0.9412
# 12/28 22:45:26 - mmengine - INFO - Epoch(train)   [8][300/792]  base_lr: 9.9989e-04 lr: 9.9989e-04  eta: 6:43:08  time: 0.2843  data_time: 0.2046  memory: 3057  loss: 0.9095
# 12/28 22:45:55 - mmengine - INFO - Epoch(train)   [8][400/792]  base_lr: 9.9989e-04 lr: 9.9989e-04  eta: 6:41:41  time: 0.2908  data_time: 0.2114  memory: 3057  loss: 0.8567
# 12/28 22:46:11 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:46:24 - mmengine - INFO - Epoch(train)   [8][500/792]  base_lr: 9.9989e-04 lr: 9.9989e-04  eta: 6:40:26  time: 0.3109  data_time: 0.2318  memory: 3057  loss: 0.8382
# 12/28 22:46:57 - mmengine - INFO - Epoch(train)   [8][600/792]  base_lr: 9.9989e-04 lr: 9.9989e-04  eta: 6:39:55  time: 0.3628  data_time: 0.2836  memory: 3057  loss: 0.9839
# 12/28 22:47:41 - mmengine - INFO - Epoch(train)   [8][700/792]  base_lr: 9.9989e-04 lr: 9.9989e-04  eta: 6:41:26  time: 0.4069  data_time: 0.3265  memory: 3057  loss: 0.9052
# 12/28 22:48:21 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:48:21 - mmengine - INFO - Saving checkpoint at 8 epochs
# 12/28 22:49:00 - mmengine - INFO - Epoch(val)   [8][100/792]    eta: 0:04:21  time: 0.5538  data_time: 0.5219  memory: 3057
# 12/28 22:49:32 - mmengine - INFO - Epoch(val)   [8][200/792]    eta: 0:03:26  time: 0.3873  data_time: 0.3611  memory: 704
# 12/28 22:50:03 - mmengine - INFO - Epoch(val)   [8][300/792]    eta: 0:02:45  time: 0.4161  data_time: 0.3898  memory: 704
# 12/28 22:50:37 - mmengine - INFO - Epoch(val)   [8][400/792]    eta: 0:02:11  time: 0.2256  data_time: 0.1992  memory: 704
# 12/28 22:50:58 - mmengine - INFO - Epoch(val)   [8][500/792]    eta: 0:01:30  time: 0.1954  data_time: 0.1692  memory: 704
# 12/28 22:51:17 - mmengine - INFO - Epoch(val)   [8][600/792]    eta: 0:00:55  time: 0.2547  data_time: 0.2285  memory: 704
# 12/28 22:51:51 - mmengine - INFO - Epoch(val)   [8][700/792]    eta: 0:00:27  time: 0.4172  data_time: 0.3911  memory: 704
# 12/28 22:53:13 - mmengine - INFO - Epoch(val) [8][792/792]    accuracy/top1: 66.1758  accuracy/top3: 93.9244  data_time: 0.3406  time: 0.3669
# 12/28 22:53:40 - mmengine - INFO - Epoch(train)   [9][100/792]  base_lr: 9.9975e-04 lr: 9.9975e-04  eta: 6:40:55  time: 0.2588  data_time: 0.1786  memory: 3057  loss: 0.7391
# 12/28 22:54:06 - mmengine - INFO - Epoch(train)   [9][200/792]  base_lr: 9.9975e-04 lr: 9.9975e-04  eta: 6:39:06  time: 0.2726  data_time: 0.1938  memory: 3057  loss: 0.9297
# 12/28 22:54:33 - mmengine - INFO - Epoch(train)   [9][300/792]  base_lr: 9.9975e-04 lr: 9.9975e-04  eta: 6:37:30  time: 0.2490  data_time: 0.1699  memory: 3057  loss: 0.9041
# 12/28 22:55:01 - mmengine - INFO - Epoch(train)   [9][400/792]  base_lr: 9.9975e-04 lr: 9.9975e-04  eta: 6:36:04  time: 0.3029  data_time: 0.2229  memory: 3057  loss: 0.9014
# 12/28 22:55:33 - mmengine - INFO - Epoch(train)   [9][500/792]  base_lr: 9.9975e-04 lr: 9.9975e-04  eta: 6:35:23  time: 0.4373  data_time: 0.3579  memory: 3057  loss: 0.8369
# 12/28 22:56:06 - mmengine - INFO - Epoch(train)   [9][600/792]  base_lr: 9.9975e-04 lr: 9.9975e-04  eta: 6:34:57  time: 0.3504  data_time: 0.2712  memory: 3057  loss: 0.7766
# 12/28 22:56:31 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:56:46 - mmengine - INFO - Epoch(train)   [9][700/792]  base_lr: 9.9975e-04 lr: 9.9975e-04  eta: 6:35:35  time: 0.4057  data_time: 0.3264  memory: 3057  loss: 0.8943
# 12/28 22:57:23 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 22:57:23 - mmengine - INFO - Saving checkpoint at 9 epochs
# 12/28 22:58:03 - mmengine - INFO - Epoch(val)   [9][100/792]    eta: 0:04:24  time: 0.5868  data_time: 0.5606  memory: 3057
# 12/28 22:58:34 - mmengine - INFO - Epoch(val)   [9][200/792]    eta: 0:03:27  time: 0.3942  data_time: 0.3681  memory: 704
# 12/28 22:59:05 - mmengine - INFO - Epoch(val)   [9][300/792]    eta: 0:02:45  time: 0.3835  data_time: 0.3574  memory: 704
# 12/28 22:59:38 - mmengine - INFO - Epoch(val)   [9][400/792]    eta: 0:02:11  time: 0.2237  data_time: 0.1976  memory: 704
# 12/28 22:59:57 - mmengine - INFO - Epoch(val)   [9][500/792]    eta: 0:01:29  time: 0.1672  data_time: 0.1411  memory: 704
# 12/28 23:00:17 - mmengine - INFO - Epoch(val)   [9][600/792]    eta: 0:00:55  time: 0.1836  data_time: 0.1575  memory: 704
# 12/28 23:00:54 - mmengine - INFO - Epoch(val)   [9][700/792]    eta: 0:00:27  time: 0.6567  data_time: 0.6305  memory: 704
# 12/28 23:01:42 - mmengine - INFO - Epoch(val) [9][792/792]    accuracy/top1: 70.1630  accuracy/top3: 94.3350  data_time: 0.2984  time: 0.3245
# 12/28 23:02:09 - mmengine - INFO - Epoch(train)  [10][100/792]  base_lr: 9.9955e-04 lr: 9.9955e-04  eta: 6:34:42  time: 0.2756  data_time: 0.1965  memory: 3057  loss: 0.8469
# 12/28 23:02:35 - mmengine - INFO - Epoch(train)  [10][200/792]  base_lr: 9.9955e-04 lr: 9.9955e-04  eta: 6:33:02  time: 0.2452  data_time: 0.1661  memory: 3057  loss: 0.8488
# 12/28 23:03:02 - mmengine - INFO - Epoch(train)  [10][300/792]  base_lr: 9.9955e-04 lr: 9.9955e-04  eta: 6:31:32  time: 0.2613  data_time: 0.1820  memory: 3057  loss: 0.9084
# 12/28 23:03:30 - mmengine - INFO - Epoch(train)  [10][400/792]  base_lr: 9.9955e-04 lr: 9.9955e-04  eta: 6:30:10  time: 0.2948  data_time: 0.2158  memory: 3057  loss: 0.8614
# 12/28 23:03:58 - mmengine - INFO - Epoch(train)  [10][500/792]  base_lr: 9.9955e-04 lr: 9.9955e-04  eta: 6:29:01  time: 0.3090  data_time: 0.2296  memory: 3057  loss: 0.8505
# 12/28 23:04:31 - mmengine - INFO - Epoch(train)  [10][600/792]  base_lr: 9.9955e-04 lr: 9.9955e-04  eta: 6:28:25  time: 0.3540  data_time: 0.2730  memory: 3057  loss: 0.8382
# 12/28 23:05:10 - mmengine - INFO - Epoch(train)  [10][700/792]  base_lr: 9.9955e-04 lr: 9.9955e-04  eta: 6:28:57  time: 0.4199  data_time: 0.3396  memory: 3057  loss: 0.9589
# 12/28 23:05:48 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 23:05:49 - mmengine - INFO - Saving checkpoint at 10 epochs
# 12/28 23:06:28 - mmengine - INFO - Epoch(val)  [10][100/792]    eta: 0:04:20  time: 0.3766  data_time: 0.3504  memory: 3057
# 12/28 23:07:00 - mmengine - INFO - Epoch(val)  [10][200/792]    eta: 0:03:27  time: 0.4101  data_time: 0.3839  memory: 704
# 12/28 23:07:32 - mmengine - INFO - Epoch(val)  [10][300/792]    eta: 0:02:46  time: 0.4032  data_time: 0.3770  memory: 704
# 12/28 23:08:09 - mmengine - INFO - Epoch(val)  [10][400/792]    eta: 0:02:15  time: 0.2851  data_time: 0.2587  memory: 704
# 12/28 23:08:29 - mmengine - INFO - Epoch(val)  [10][500/792]    eta: 0:01:32  time: 0.1858  data_time: 0.1595  memory: 704
# 12/28 23:08:48 - mmengine - INFO - Epoch(val)  [10][600/792]    eta: 0:00:56  time: 0.2021  data_time: 0.1759  memory: 704
# 12/28 23:09:23 - mmengine - INFO - Epoch(val)  [10][700/792]    eta: 0:00:27  time: 0.4509  data_time: 0.4246  memory: 704
# 12/28 23:10:02 - mmengine - INFO - Epoch(val) [10][792/792]    accuracy/top1: 69.0458  accuracy/top3: 93.4744  data_time: 0.2910  time: 0.3172
# 12/28 23:10:23 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/28 23:10:28 - mmengine - INFO - Epoch(train)  [11][100/792]  base_lr: 9.9930e-04 lr: 9.9930e-04  eta: 6:28:12  time: 0.2769  data_time: 0.1976  memory: 3057  loss: 0.8612
# ...
# 12/29 08:04:55 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:04:55 - mmengine - INFO - Saving checkpoint at 94 epochs
# 12/29 08:05:23 - mmengine - INFO - Epoch(val)  [94][100/792]    eta: 0:03:08  time: 0.3046  data_time: 0.2783  memory: 3057
# 12/29 08:05:47 - mmengine - INFO - Epoch(val)  [94][200/792]    eta: 0:02:31  time: 0.3101  data_time: 0.2838  memory: 704
# 12/29 08:06:10 - mmengine - INFO - Epoch(val)  [94][300/792]    eta: 0:02:01  time: 0.3103  data_time: 0.2841  memory: 704
# 12/29 08:06:36 - mmengine - INFO - Epoch(val)  [94][400/792]    eta: 0:01:38  time: 0.1963  data_time: 0.1699  memory: 704
# 12/29 08:06:52 - mmengine - INFO - Epoch(val)  [94][500/792]    eta: 0:01:07  time: 0.1395  data_time: 0.1134  memory: 704
# 12/29 08:07:06 - mmengine - INFO - Epoch(val)  [94][600/792]    eta: 0:00:41  time: 0.1379  data_time: 0.1118  memory: 704
# 12/29 08:07:31 - mmengine - INFO - Epoch(val)  [94][700/792]    eta: 0:00:20  time: 0.3121  data_time: 0.2858  memory: 704
# 12/29 08:07:58 - mmengine - INFO - Epoch(val) [94][792/792]    accuracy/top1: 91.4532  accuracy/top3: 99.7000  data_time: 0.2031  time: 0.2294
# 12/29 08:08:22 - mmengine - INFO - Epoch(train)  [95][100/792]  base_lr: 7.9382e-04 lr: 7.9382e-04  eta: 0:19:38  time: 0.2454  data_time: 0.1660  memory: 3057  loss: 0.3530
# 12/29 08:08:46 - mmengine - INFO - Epoch(train)  [95][200/792]  base_lr: 7.9382e-04 lr: 7.9382e-04  eta: 0:19:13  time: 0.2347  data_time: 0.1554  memory: 3057  loss: 0.4098
# 12/29 08:09:09 - mmengine - INFO - Epoch(train)  [95][300/792]  base_lr: 7.9382e-04 lr: 7.9382e-04  eta: 0:18:48  time: 0.2422  data_time: 0.1632  memory: 3057  loss: 0.4158
# 12/29 08:09:33 - mmengine - INFO - Epoch(train)  [95][400/792]  base_lr: 7.9382e-04 lr: 7.9382e-04  eta: 0:18:22  time: 0.2339  data_time: 0.1542  memory: 3057  loss: 0.4104
# 12/29 08:09:56 - mmengine - INFO - Epoch(train)  [95][500/792]  base_lr: 7.9382e-04 lr: 7.9382e-04  eta: 0:17:57  time: 0.2388  data_time: 0.1591  memory: 3057  loss: 0.4392
# 12/29 08:10:09 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:10:20 - mmengine - INFO - Epoch(train)  [95][600/792]  base_lr: 7.9382e-04 lr: 7.9382e-04  eta: 0:17:31  time: 0.2288  data_time: 0.1491  memory: 3057  loss: 0.4307
# 12/29 08:10:44 - mmengine - INFO - Epoch(train)  [95][700/792]  base_lr: 7.9382e-04 lr: 7.9382e-04  eta: 0:17:06  time: 0.2372  data_time: 0.1579  memory: 3057  loss: 0.4354
# 12/29 08:11:06 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:11:06 - mmengine - INFO - Saving checkpoint at 95 epochs
# 12/29 08:11:34 - mmengine - INFO - Epoch(val)  [95][100/792]    eta: 0:03:08  time: 0.3031  data_time: 0.2768  memory: 3057
# 12/29 08:11:58 - mmengine - INFO - Epoch(val)  [95][200/792]    eta: 0:02:31  time: 0.3088  data_time: 0.2826  memory: 704
# 12/29 08:12:20 - mmengine - INFO - Epoch(val)  [95][300/792]    eta: 0:02:01  time: 0.3100  data_time: 0.2838  memory: 704
# 12/29 08:12:47 - mmengine - INFO - Epoch(val)  [95][400/792]    eta: 0:01:38  time: 0.1969  data_time: 0.1706  memory: 704
# 12/29 08:13:03 - mmengine - INFO - Epoch(val)  [95][500/792]    eta: 0:01:07  time: 0.1393  data_time: 0.1131  memory: 704
# 12/29 08:13:17 - mmengine - INFO - Epoch(val)  [95][600/792]    eta: 0:00:41  time: 0.1382  data_time: 0.1057  memory: 704
# 12/29 08:13:42 - mmengine - INFO - Epoch(val)  [95][700/792]    eta: 0:00:20  time: 0.3121  data_time: 0.2858  memory: 704
# 12/29 08:14:09 - mmengine - INFO - Epoch(val) [95][792/792]    accuracy/top1: 92.0137  accuracy/top3: 99.7316  data_time: 0.2031  time: 0.2294
# 12/29 08:14:33 - mmengine - INFO - Epoch(train)  [96][100/792]  base_lr: 7.8952e-04 lr: 7.8952e-04  eta: 0:16:17  time: 0.2420  data_time: 0.1627  memory: 3057  loss: 0.3763
# 12/29 08:14:57 - mmengine - INFO - Epoch(train)  [96][200/792]  base_lr: 7.8952e-04 lr: 7.8952e-04  eta: 0:15:52  time: 0.2394  data_time: 0.1600  memory: 3057  loss: 0.4622
# 12/29 08:15:20 - mmengine - INFO - Epoch(train)  [96][300/792]  base_lr: 7.8952e-04 lr: 7.8952e-04  eta: 0:15:26  time: 0.2341  data_time: 0.1546  memory: 3057  loss: 0.4515
# 12/29 08:15:44 - mmengine - INFO - Epoch(train)  [96][400/792]  base_lr: 7.8952e-04 lr: 7.8952e-04  eta: 0:15:01  time: 0.2275  data_time: 0.1479  memory: 3057  loss: 0.4713
# 12/29 08:16:08 - mmengine - INFO - Epoch(train)  [96][500/792]  base_lr: 7.8952e-04 lr: 7.8952e-04  eta: 0:14:35  time: 0.2349  data_time: 0.1556  memory: 3057  loss: 0.4287
# 12/29 08:16:31 - mmengine - INFO - Epoch(train)  [96][600/792]  base_lr: 7.8952e-04 lr: 7.8952e-04  eta: 0:14:10  time: 0.2499  data_time: 0.1708  memory: 3057  loss: 0.3805
# 12/29 08:16:55 - mmengine - INFO - Epoch(train)  [96][700/792]  base_lr: 7.8952e-04 lr: 7.8952e-04  eta: 0:13:45  time: 0.2456  data_time: 0.1653  memory: 3057  loss: 0.4348
# 12/29 08:17:09 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:17:17 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:17:17 - mmengine - INFO - Saving checkpoint at 96 epochs
# 12/29 08:17:45 - mmengine - INFO - Epoch(val)  [96][100/792]    eta: 0:03:08  time: 0.3052  data_time: 0.2789  memory: 3057
# 12/29 08:18:09 - mmengine - INFO - Epoch(val)  [96][200/792]    eta: 0:02:31  time: 0.3086  data_time: 0.2824  memory: 704
# 12/29 08:18:31 - mmengine - INFO - Epoch(val)  [96][300/792]    eta: 0:02:01  time: 0.3098  data_time: 0.2835  memory: 704
# 12/29 08:18:58 - mmengine - INFO - Epoch(val)  [96][400/792]    eta: 0:01:38  time: 0.1961  data_time: 0.1697  memory: 704
# 12/29 08:19:14 - mmengine - INFO - Epoch(val)  [96][500/792]    eta: 0:01:07  time: 0.1393  data_time: 0.1132  memory: 704
# 12/29 08:19:27 - mmengine - INFO - Epoch(val)  [96][600/792]    eta: 0:00:41  time: 0.1383  data_time: 0.1121  memory: 704
# 12/29 08:19:53 - mmengine - INFO - Epoch(val)  [96][700/792]    eta: 0:00:20  time: 0.3125  data_time: 0.2861  memory: 704
# 12/29 08:20:19 - mmengine - INFO - Epoch(val) [96][792/792]    accuracy/top1: 90.2412  accuracy/top3: 99.7237  data_time: 0.2031  time: 0.2293
# 12/29 08:20:43 - mmengine - INFO - Epoch(train)  [97][100/792]  base_lr: 7.8519e-04 lr: 7.8519e-04  eta: 0:12:56  time: 0.2285  data_time: 0.1496  memory: 3057  loss: 0.3936
# 12/29 08:21:07 - mmengine - INFO - Epoch(train)  [97][200/792]  base_lr: 7.8519e-04 lr: 7.8519e-04  eta: 0:12:31  time: 0.2437  data_time: 0.1643  memory: 3057  loss: 0.4131
# 12/29 08:21:30 - mmengine - INFO - Epoch(train)  [97][300/792]  base_lr: 7.8519e-04 lr: 7.8519e-04  eta: 0:12:05  time: 0.2391  data_time: 0.1596  memory: 3057  loss: 0.4307
# 12/29 08:21:54 - mmengine - INFO - Epoch(train)  [97][400/792]  base_lr: 7.8519e-04 lr: 7.8519e-04  eta: 0:11:40  time: 0.2241  data_time: 0.1444  memory: 3057  loss: 0.4416
# 12/29 08:22:18 - mmengine - INFO - Epoch(train)  [97][500/792]  base_lr: 7.8519e-04 lr: 7.8519e-04  eta: 0:11:15  time: 0.2377  data_time: 0.1580  memory: 3057  loss: 0.4785
# 12/29 08:22:42 - mmengine - INFO - Epoch(train)  [97][600/792]  base_lr: 7.8519e-04 lr: 7.8519e-04  eta: 0:10:49  time: 0.2411  data_time: 0.1619  memory: 3057  loss: 0.3534
# 12/29 08:23:06 - mmengine - INFO - Epoch(train)  [97][700/792]  base_lr: 7.8519e-04 lr: 7.8519e-04  eta: 0:10:24  time: 0.2520  data_time: 0.1723  memory: 3057  loss: 0.4056
# 12/29 08:23:27 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:23:27 - mmengine - INFO - Saving checkpoint at 97 epochs
# 12/29 08:23:55 - mmengine - INFO - Epoch(val)  [97][100/792]    eta: 0:03:08  time: 0.3051  data_time: 0.2788  memory: 3057
# 12/29 08:24:19 - mmengine - INFO - Epoch(val)  [97][200/792]    eta: 0:02:31  time: 0.3104  data_time: 0.2841  memory: 704
# 12/29 08:24:42 - mmengine - INFO - Epoch(val)  [97][300/792]    eta: 0:02:01  time: 0.3093  data_time: 0.2830  memory: 704
# 12/29 08:25:09 - mmengine - INFO - Epoch(val)  [97][400/792]    eta: 0:01:38  time: 0.1971  data_time: 0.1708  memory: 704
# 12/29 08:25:24 - mmengine - INFO - Epoch(val)  [97][500/792]    eta: 0:01:07  time: 0.1391  data_time: 0.1129  memory: 704
# 12/29 08:25:38 - mmengine - INFO - Epoch(val)  [97][600/792]    eta: 0:00:41  time: 0.1322  data_time: 0.1058  memory: 704
# 12/29 08:26:04 - mmengine - INFO - Epoch(val)  [97][700/792]    eta: 0:00:20  time: 0.3112  data_time: 0.2849  memory: 704
# 12/29 08:26:30 - mmengine - INFO - Epoch(val) [97][792/792]    accuracy/top1: 89.7991  accuracy/top3: 99.5105  data_time: 0.2029  time: 0.2292
# 12/29 08:26:54 - mmengine - INFO - Epoch(train)  [98][100/792]  base_lr: 7.8083e-04 lr: 7.8083e-04  eta: 0:09:35  time: 0.2413  data_time: 0.1619  memory: 3057  loss: 0.3010
# 12/29 08:27:12 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:27:18 - mmengine - INFO - Epoch(train)  [98][200/792]  base_lr: 7.8083e-04 lr: 7.8083e-04  eta: 0:09:10  time: 0.2378  data_time: 0.1583  memory: 3057  loss: 0.3891
# 12/29 08:27:42 - mmengine - INFO - Epoch(train)  [98][300/792]  base_lr: 7.8083e-04 lr: 7.8083e-04  eta: 0:08:44  time: 0.2390  data_time: 0.1594  memory: 3057  loss: 0.4321
# 12/29 08:28:05 - mmengine - INFO - Epoch(train)  [98][400/792]  base_lr: 7.8083e-04 lr: 7.8083e-04  eta: 0:08:19  time: 0.2358  data_time: 0.1569  memory: 3057  loss: 0.4494
# 12/29 08:28:30 - mmengine - INFO - Epoch(train)  [98][500/792]  base_lr: 7.8083e-04 lr: 7.8083e-04  eta: 0:07:54  time: 0.2442  data_time: 0.1647  memory: 3057  loss: 0.4889
# 12/29 08:28:53 - mmengine - INFO - Epoch(train)  [98][600/792]  base_lr: 7.8083e-04 lr: 7.8083e-04  eta: 0:07:29  time: 0.2373  data_time: 0.1578  memory: 3057  loss: 0.5326
# 12/29 08:29:17 - mmengine - INFO - Epoch(train)  [98][700/792]  base_lr: 7.8083e-04 lr: 7.8083e-04  eta: 0:07:03  time: 0.2367  data_time: 0.1572  memory: 3057  loss: 0.4036
# 12/29 08:29:38 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:29:38 - mmengine - INFO - Saving checkpoint at 98 epochs
# 12/29 08:30:06 - mmengine - INFO - Epoch(val)  [98][100/792]    eta: 0:03:07  time: 0.3018  data_time: 0.2755  memory: 3057
# 12/29 08:30:30 - mmengine - INFO - Epoch(val)  [98][200/792]    eta: 0:02:30  time: 0.3088  data_time: 0.2826  memory: 704
# 12/29 08:30:53 - mmengine - INFO - Epoch(val)  [98][300/792]    eta: 0:02:00  time: 0.3096  data_time: 0.2834  memory: 704
# 12/29 08:31:19 - mmengine - INFO - Epoch(val)  [98][400/792]    eta: 0:01:38  time: 0.1972  data_time: 0.1710  memory: 704
# 12/29 08:31:35 - mmengine - INFO - Epoch(val)  [98][500/792]    eta: 0:01:07  time: 0.1394  data_time: 0.1132  memory: 704
# 12/29 08:31:49 - mmengine - INFO - Epoch(val)  [98][600/792]    eta: 0:00:41  time: 0.1380  data_time: 0.1118  memory: 704
# 12/29 08:32:14 - mmengine - INFO - Epoch(val)  [98][700/792]    eta: 0:00:20  time: 0.3109  data_time: 0.2847  memory: 704
# 12/29 08:32:41 - mmengine - INFO - Epoch(val) [98][792/792]    accuracy/top1: 89.6925  accuracy/top3: 99.6644  data_time: 0.2025  time: 0.2288
# 12/29 08:33:05 - mmengine - INFO - Epoch(train)  [99][100/792]  base_lr: 7.7644e-04 lr: 7.7644e-04  eta: 0:06:15  time: 0.2412  data_time: 0.1617  memory: 3057  loss: 0.4134
# 12/29 08:33:29 - mmengine - INFO - Epoch(train)  [99][200/792]  base_lr: 7.7644e-04 lr: 7.7644e-04  eta: 0:05:49  time: 0.2438  data_time: 0.1644  memory: 3057  loss: 0.3363
# 12/29 08:33:53 - mmengine - INFO - Epoch(train)  [99][300/792]  base_lr: 7.7644e-04 lr: 7.7644e-04  eta: 0:05:24  time: 0.2491  data_time: 0.1695  memory: 3057  loss: 0.4536
# 12/29 08:34:12 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:34:16 - mmengine - INFO - Epoch(train)  [99][400/792]  base_lr: 7.7644e-04 lr: 7.7644e-04  eta: 0:04:59  time: 0.2523  data_time: 0.1728  memory: 3057  loss: 0.3872
# 12/29 08:34:40 - mmengine - INFO - Epoch(train)  [99][500/792]  base_lr: 7.7644e-04 lr: 7.7644e-04  eta: 0:04:33  time: 0.2350  data_time: 0.1556  memory: 3057  loss: 0.4178
# 12/29 08:35:04 - mmengine - INFO - Epoch(train)  [99][600/792]  base_lr: 7.7644e-04 lr: 7.7644e-04  eta: 0:04:08  time: 0.2329  data_time: 0.1535  memory: 3057  loss: 0.4391
# 12/29 08:35:27 - mmengine - INFO - Epoch(train)  [99][700/792]  base_lr: 7.7644e-04 lr: 7.7644e-04  eta: 0:03:43  time: 0.2385  data_time: 0.1589  memory: 3057  loss: 0.4445
# 12/29 08:35:49 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:35:49 - mmengine - INFO - Saving checkpoint at 99 epochs
# 12/29 08:36:17 - mmengine - INFO - Epoch(val)  [99][100/792]    eta: 0:03:08  time: 0.3047  data_time: 0.2785  memory: 3057
# 12/29 08:36:41 - mmengine - INFO - Epoch(val)  [99][200/792]    eta: 0:02:31  time: 0.3106  data_time: 0.2843  memory: 704
# 12/29 08:37:04 - mmengine - INFO - Epoch(val)  [99][300/792]    eta: 0:02:01  time: 0.3102  data_time: 0.2840  memory: 704
# 12/29 08:37:30 - mmengine - INFO - Epoch(val)  [99][400/792]    eta: 0:01:38  time: 0.1972  data_time: 0.1709  memory: 704
# 12/29 08:37:46 - mmengine - INFO - Epoch(val)  [99][500/792]    eta: 0:01:07  time: 0.1388  data_time: 0.1126  memory: 704
# 12/29 08:38:00 - mmengine - INFO - Epoch(val)  [99][600/792]    eta: 0:00:41  time: 0.1389  data_time: 0.1127  memory: 704
# 12/29 08:38:25 - mmengine - INFO - Epoch(val)  [99][700/792]    eta: 0:00:20  time: 0.3135  data_time: 0.2873  memory: 704
# 12/29 08:38:52 - mmengine - INFO - Epoch(val) [99][792/792]    accuracy/top1: 93.0125  accuracy/top3: 99.7237  data_time: 0.2030  time: 0.2293
# 12/29 08:39:15 - mmengine - INFO - Epoch(train) [100][100/792]  base_lr: 7.7201e-04 lr: 7.7201e-04  eta: 0:02:54  time: 0.2410  data_time: 0.1617  memory: 3057  loss: 0.3785
# 12/29 08:39:39 - mmengine - INFO - Epoch(train) [100][200/792]  base_lr: 7.7201e-04 lr: 7.7201e-04  eta: 0:02:29  time: 0.2441  data_time: 0.1647  memory: 3057  loss: 0.4081
# 12/29 08:40:03 - mmengine - INFO - Epoch(train) [100][300/792]  base_lr: 7.7201e-04 lr: 7.7201e-04  eta: 0:02:04  time: 0.2385  data_time: 0.1594  memory: 3057  loss: 0.4129
# 12/29 08:40:27 - mmengine - INFO - Epoch(train) [100][400/792]  base_lr: 7.7201e-04 lr: 7.7201e-04  eta: 0:01:39  time: 0.2373  data_time: 0.1578  memory: 3057  loss: 0.3469
# 12/29 08:40:50 - mmengine - INFO - Epoch(train) [100][500/792]  base_lr: 7.7201e-04 lr: 7.7201e-04  eta: 0:01:13  time: 0.2353  data_time: 0.1561  memory: 3057  loss: 0.3898
# 12/29 08:41:12 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:41:14 - mmengine - INFO - Epoch(train) [100][600/792]  base_lr: 7.7201e-04 lr: 7.7201e-04  eta: 0:00:48  time: 0.2380  data_time: 0.1588  memory: 3057  loss: 0.3035
# 12/29 08:41:38 - mmengine - INFO - Epoch(train) [100][700/792]  base_lr: 7.7201e-04 lr: 7.7201e-04  eta: 0:00:23  time: 0.2291  data_time: 0.1498  memory: 3057  loss: 0.4914
# 12/29 08:42:00 - mmengine - INFO - Exp name: resnet50_ISIC_2019_20231228_214318
# 12/29 08:42:00 - mmengine - INFO - Saving checkpoint at 100 epochs
# 12/29 08:42:28 - mmengine - INFO - Epoch(val) [100][100/792]    eta: 0:03:08  time: 0.3039  data_time: 0.2776  memory: 3057
# 12/29 08:42:52 - mmengine - INFO - Epoch(val) [100][200/792]    eta: 0:02:31  time: 0.3102  data_time: 0.2840  memory: 704
# 12/29 08:43:14 - mmengine - INFO - Epoch(val) [100][300/792]    eta: 0:02:01  time: 0.3097  data_time: 0.2834  memory: 704
# 12/29 08:43:41 - mmengine - INFO - Epoch(val) [100][400/792]    eta: 0:01:38  time: 0.1979  data_time: 0.1717  memory: 704
# 12/29 08:43:56 - mmengine - INFO - Epoch(val) [100][500/792]    eta: 0:01:07  time: 0.1390  data_time: 0.1127  memory: 704
# 12/29 08:44:10 - mmengine - INFO - Epoch(val) [100][600/792]    eta: 0:00:41  time: 0.1379  data_time: 0.1118  memory: 704
# 12/29 08:44:36 - mmengine - INFO - Epoch(val) [100][700/792]    eta: 0:00:20  time: 0.3129  data_time: 0.2866  memory: 704
# 12/29 08:45:02 - mmengine - INFO - Epoch(val) [100][792/792]    accuracy/top1: 91.5716  accuracy/top3: 99.6408  data_time: 0.2028  time: 0.2291

# %%
# !python tools/analysis_tools/analyze_logs.py plot_curve work_dirs/ISIC/2019/Resnet50/20231228_214318/vis_data/20231228_214318.json --keys accuracy/top1 accuracy/top3  --legend top1 top3 --out results_resnet50.jpg
# Out:
# plot curve of work_dirs/ISIC/2019/Resnet50/20231228_214318/vis_data/20231228_214318.json, metric is accuracy/top1
# plot curve of work_dirs/ISIC/2019/Resnet50/20231228_214318/vis_data/20231228_214318.json, metric is accuracy/top3
# save curve to: results_resnet50.jpg
