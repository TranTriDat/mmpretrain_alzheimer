# %%
# Check PyTorch installation
import torch, torchvision
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 1.10.1
# True

# %%
# %%writefile configs/resnet/resnet18_alzheimer_axial_view.py
_base_ = [
    '../_base_/models/resnet18.py', 
    # '../_base_/schedules/cifar10_bs128.py', 
    '../_base_/schedules/imagenet_bs1024_adamw_conformer.py',
    # '../_base_/schedules/imagenet_bs256.py',
    '../_base_/default_runtime.py'
]

pretrained='https://download.openmmlab.com/mmclassification/v0/resnet/resnet18_b16x8_cifar10_20210528-bd6371c8.pth'

model = dict(
    type='ImageClassifier',
    backbone=dict(
        type='ResNet', 
        style='pytorch',
        init_cfg=dict(
            type='Pretrained',
            checkpoint=pretrained,
            prefix='backbone'
        ),
    ),
    head=dict(
        num_classes=3,
        topk=(1, 3),
    ))

dataset_type = 'CustomDataset'
# dataset_type = 'ImageNet'
data_preprocessor = dict(
     # mean=[124.508, 116.050, 106.438],
     # std=[58.577, 57.310, 57.437],
     mean=[124.508, 116.050, 106.438],
     std=[58.577, 57.310, 57.437],
     to_rgb=False)

# data_preprocessor = dict(
#     # Input image data channels in 'RGB' order
#     mean=[123.675, 116.28, 103.53],    # Input image normalized channel mean in RGB order
#     std=[58.395, 57.12, 57.375],       # Input image normalized channel std in RGB order
#     to_rgb=True,                       # Whether to flip the channel from BGR to RGB or RGB to BGR
# )
train_pipeline = [
    dict(type='LoadImageFromFile'),     # read image
    # dict(type='ResizeEdge', scale=256),  # Scale the short side to 256
    # dict(type='RandomResizedCrop', scale=224), # 224x224
    dict(type='RandomFlip', prob=0.5, direction='horizontal'),   # random horizontal flip
    dict(type='PackInputs'),
]
test_pipeline = [
    dict(type='LoadImageFromFile'),     # read image
    # dict(type='ResizeEdge', scale=256),  # Scale the short side to 256
    # dict(type='CenterCrop', crop_size=224),
    dict(type='PackInputs'),    
]

train_dataloader = dict(
    batch_size=32,
    num_workers=5,
    dataset=dict(
        type=dataset_type,
        data_root='data',
        data_prefix='YoriDataset_vgg/train',
        ann_file='train_ann.txt',
        classes='data/classes.txt',
        with_label=True,
        pipeline=train_pipeline
    ),
    sampler=dict(type='DefaultSampler', shuffle=True),
    persistent_workers=True
)

val_dataloader = dict(
    batch_size=32,
    num_workers=5,
    dataset=dict(
        type=dataset_type,
        data_root='data',
        data_prefix='YoriDataset_vgg/validation',
        classes='data/classes.txt',
        ann_file='val_ann.txt',
        with_label=True,
        pipeline=test_pipeline
    ),
    sampler=dict(type='DefaultSampler', shuffle=False),
    persistent_workers=True
)

test_dataloader = dict(
    batch_size=32,
    num_workers=5,
    dataset=dict(
        type=dataset_type,
        data_root='data',
        data_prefix='YoriDataset_vgg/test',
        classes='data/classes.txt',
        ann_file='test_ann.txt',
        with_label=True,
        pipeline=test_pipeline
    ),    
    sampler=dict(type='DefaultSampler', shuffle=False),
    persistent_workers=True
)

val_evaluator = dict(type='Accuracy', topk=(1, 3))
test_evaluator = val_evaluator 

# optim_wrapper = dict(
#     # Use SGD optimizer to optimize parameters.
#     optimizer=dict(type='SGD', lr=0.1, momentum=0.9, weight_decay=0.0001))

# # The tuning strategy of the learning rate.
# # The 'MultiStepLR' means to use multiple steps policy to schedule the learning rate (LR).
# param_scheduler = dict(
#     type='MultiStepLR', by_epoch=True, milestones=[30, 60, 90], gamma=0.1)

optim_wrapper = dict(
    optimizer=dict(
        type='AdamW',
        # for batch in each gpu is 128, 8 gpu
        # lr = 5e-4 * 128 * 8 / 512 = 0.001
        lr=5e-4 * 128 * 8 / 512,
        weight_decay=0.05,
        eps=1e-8,
        betas=(0.9, 0.999)),
    paramwise_cfg=dict(
        norm_decay_mult=0.0,
        bias_decay_mult=0.0,
        custom_keys={
            '.cls_token': dict(decay_mult=0.0),
        }),
)

# learning policy
param_scheduler = [
    dict(
        type='LinearLR',
        start_factor=1e-3,
        by_epoch=True,
        begin=0,
        end=5,
        convert_to_iter_based=True),
    dict(
        type='CosineAnnealingLR',
        T_max=295,
        eta_min=1e-5,
        by_epoch=True,
        begin=5,
        end=300)
]

train_cfg = dict(by_epoch=True, max_epochs=3, val_interval=1)
val_cfg = dict()
test_cfg = dict()

auto_scale_lr = dict(base_batch_size=256)

default_scope = 'mmpretrain'

# configure default hooks
default_hooks = dict(
    # record the time of every iteration.
    timer=dict(type='IterTimerHook'),

    # print log every 100 iterations.
    logger=dict(type='LoggerHook', interval=100),

    # enable the parameter scheduler.
    param_scheduler=dict(type='ParamSchedulerHook'),

    # save checkpoint per epoch.
    checkpoint=dict(type='CheckpointHook', interval=1),

    # set sampler seed in a distributed environment.
    sampler_seed=dict(type='DistSamplerSeedHook'),

    # validation results visualization, set True to enable it.
    visualization=dict(type='VisualizationHook', enable=False),
)

env_cfg = dict(
    # whether to enable cudnn benchmark
    cudnn_benchmark=False,

    # set multi-process parameters
    mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),

    # set distributed parameters
    dist_cfg=dict(backend='nccl'),
)

# set visualizer
vis_backends = [dict(type='LocalVisBackend')]  # use local HDD backend
visualizer = dict(type='UniversalVisualizer', vis_backends=vis_backends, name='visualizer')

# set log level
log_level = 'INFO'

# load from which checkpoint
load_from = None

# whether to resume training from the loaded checkpoint
resume = False
# Out:
# Overwriting configs/resnet/resnet18_alzheimer_axial_view.py

# %%
# !python ./tools/train.py \
    configs/resnet/resnet18_alzheimer_axial_view.py \
    --work-dir work_dirs/alzheimer/axial/resnet18 \
    # --auto-scale-lr
# Out:
# configs/resnet/resnet18_alzheimer_axial_view.py
# 11/18 16:55:29 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.18 (default, Sep 11 2023, 13:40:15) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 360360474
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: /usr/local/cuda-11.4
#     NVCC: Cuda compilation tools, release 11.4, V11.4.100
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.10.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.2
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.11.2
#     OpenCV: 4.8.1
#     MMEngine: 0.9.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 360360474
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/18 16:55:29 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=256)
# data_preprocessor = dict(
#     mean=[
#         124.508,
#         116.05,
#         106.438,
#     ],
#     std=[
#         58.577,
#         57.31,
#         57.437,
#     ],
#     to_rgb=False)
# dataset_type = 'CustomDataset'
# default_hooks = dict(
#     checkpoint=dict(interval=1, type='CheckpointHook'),
#     logger=dict(interval=100, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(enable=False, type='VisualizationHook'))
# default_scope = 'mmpretrain'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# model = dict(
#     backbone=dict(
#         depth=18,
#         init_cfg=dict(
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/resnet/resnet18_b16x8_cifar10_20210528-bd6371c8.pth',
#             prefix='backbone',
#             type='Pretrained'),
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch',
#         type='ResNet'),
#     head=dict(
#         in_channels=512,
#         loss=dict(loss_weight=1.0, type='CrossEntropyLoss'),
#         num_classes=3,
#         topk=(
#             1,
#             3,
#         ),
#         type='LinearClsHead'),
#     neck=dict(type='GlobalAveragePooling'),
#     type='ImageClassifier')
# optim_wrapper = dict(
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ),
#         eps=1e-08,
#         lr=0.001,
#         type='AdamW',
#         weight_decay=0.05),
#     paramwise_cfg=dict(
#         bias_decay_mult=0.0,
#         custom_keys=dict({'.cls_token': dict(decay_mult=0.0)}),
#         norm_decay_mult=0.0))
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=5,
#         start_factor=0.001,
#         type='LinearLR'),
#     dict(
#         T_max=295,
#         begin=5,
#         by_epoch=True,
#         end=300,
#         eta_min=1e-05,
#         type='CosineAnnealingLR'),
# ]
# pretrained = 'https://download.openmmlab.com/mmclassification/v0/resnet/resnet18_b16x8_cifar10_20210528-bd6371c8.pth'
# randomness = dict(deterministic=False, seed=None)
# resume = False
# test_cfg = dict()
# test_dataloader = dict(
#     batch_size=32,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file='test_ann.txt',
#         classes='data/classes.txt',
#         data_prefix='YoriDataset_vgg/test',
#         data_root='data',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(scale=256, type='ResizeEdge'),
#             dict(type='PackInputs'),
#         ],
#         type='CustomDataset',
#         with_label=True),
#     num_workers=5,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     topk=(
#         1,
#         3,
#     ), type='Accuracy')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(scale=256, type='ResizeEdge'),
#     dict(type='PackInputs'),
# ]
# train_cfg = dict(by_epoch=True, max_epochs=3, val_interval=1)
# train_dataloader = dict(
#     batch_size=32,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file='train_ann.txt',
#         classes='data/classes.txt',
#         data_prefix='YoriDataset_vgg/train',
#         data_root='data',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(scale=256, type='ResizeEdge'),
#             dict(direction='horizontal', prob=0.5, type='RandomFlip'),
#             dict(type='PackInputs'),
#         ],
#         type='CustomDataset',
#         with_label=True),
#     num_workers=5,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(scale=256, type='ResizeEdge'),
#     dict(direction='horizontal', prob=0.5, type='RandomFlip'),
#     dict(type='PackInputs'),
# ]
# val_cfg = dict()
# val_dataloader = dict(
#     batch_size=32,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file='val_ann.txt',
#         classes='data/classes.txt',
#         data_prefix='YoriDataset_vgg/validation',
#         data_root='data',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(scale=256, type='ResizeEdge'),
#             dict(type='PackInputs'),
#         ],
#         type='CustomDataset',
#         with_label=True),
#     num_workers=5,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     topk=(
#         1,
#         3,
#     ), type='Accuracy')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='UniversalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = 'work_dirs/alzheimer/axial/resnet18'
#
# 11/18 16:55:33 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/18 16:55:33 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.bn1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.bn1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer1.0.bn1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer1.0.bn1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer1.0.bn2.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer1.0.bn2.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer1.1.bn1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer1.1.bn1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer1.1.bn2.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer1.1.bn2.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn2.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn2.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer2.0.downsample.1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer2.0.downsample.1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn2.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn2.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn2.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn2.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer3.0.downsample.1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer3.0.downsample.1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn2.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn2.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn2.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn2.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer4.0.downsample.1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer4.0.downsample.1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn1.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn1.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn2.weight:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn2.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - paramwise_options -- head.fc.bias:weight_decay=0.0
# 11/18 16:55:33 - mmengine - INFO - load backbone in model from: https://download.openmmlab.com/mmclassification/v0/resnet/resnet18_b16x8_cifar10_20210528-bd6371c8.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmclassification/v0/resnet/resnet18_b16x8_cifar10_20210528-bd6371c8.pth
# 11/18 16:55:33 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for conv1.weight: copying a param with shape torch.Size([64, 3, 3, 3]) from checkpoint, the shape in current model is torch.Size([64, 3, 7, 7]).
# 11/18 16:55:33 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 11/18 16:55:33 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 11/18 16:55:33 - mmengine - INFO - Checkpoints will be saved to /home/user/mmpretrain/work_dirs/alzheimer/axial/resnet18.
# Traceback (most recent call last):
#   File "./tools/train.py", line 162, in <module>
#     main()
#   File "./tools/train.py", line 158, in main
#     runner.train()
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/mmengine/runner/runner.py", line 1777, in train
#     model = self.train_loop.run()  # type: ignore
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/mmengine/runner/loops.py", line 96, in run
#     self.run_epoch()
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/mmengine/runner/loops.py", line 111, in run_epoch
#     for idx, data_batch in enumerate(self.dataloader):
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 521, in __next__
#     data = self._next_data()
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1203, in _next_data
#     return self._process_data(data)
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1229, in _process_data
#     data.reraise()
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/torch/_utils.py", line 434, in reraise
#     raise exception
# RuntimeError: Caught RuntimeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/torch/utils/data/_utils/worker.py", line 287, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py", line 52, in fetch
#     return self.collate_fn(data)
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/mmengine/dataset/utils.py", line 160, in default_collate
#     return data_item_type({
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/mmengine/dataset/utils.py", line 161, in <dictcomp>
#     key: default_collate([d[key] for d in data_batch])
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/mmengine/dataset/utils.py", line 165, in default_collate
#     return torch_default_collate(data_batch)
#   File "/home/user/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py", line 56, in default_collate
#     return torch.stack(batch, 0, out=out)
# RuntimeError: stack expects each tensor to be equal size, but got [3, 307, 256] at entry 0 and [3, 394, 256] at entry 1

# %%
import mmcv
from mmpretrain.apis import inference_model, init_model

config_file = 'configs/resnet/resnet18_alzheimer_axial_view.py'
checkpoint_file = 'work_dirs/alzheimer/axial/resnet18/epoch_100.pth'

# Specify the device, if you cannot use GPU, you can also use CPU 
# by specifying `device='cpu'`.
device = 'cuda:0'
# device = 'cpu'

# Build the model according to the config file and load the checkpoint.
model_axial = init_model(config_file, checkpoint_file, device=device)
model_axial.backbone.layer4
# Out:
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# ResLayer(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (drop_path): Identity()
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (drop_path): Identity()
#   )
# )

# %%
image_url='data/YoriDataset_vgg/train/MCI/100x-103.png'
image = np.array(Image.open(image_url))
image = (transforms.ToTensor()(image))

image.shape
# Out:
# torch.Size([1, 192, 160])

# %%
from pytorch_grad_cam import GradCAM, HiResCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, FullGrad
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image
from torchvision.models import resnet18
from torchvision import transforms
from PIL import Image
import numpy as np

# model = resnet50(pretrained=True)
model = model_axial

target_layers = [model.backbone.layer4[-1]]
image_url='data/YoriDataset_vgg/train/MCI/100x-103.png'
# image_url='demo/cat-dog.png'
image = np.array(Image.open(image_url))
# image = (transforms.ToTensor()(image))
rgb_img = np.float32(image) / 255
print(rgb_img.shape)
input_tensor = preprocess_image(
                                rgb_img,
                                mean=[0.485, 0.456, 0.406],
                                std=[0.229, 0.224, 0.225]
                                )
# Construct the CAM object once, and then re-use it on many images:
with GradCAM(model=model,
             target_layers=target_layers,
             use_cuda=torch.cuda.is_available()) as cam:
    
    grayscale_cam = cam(input_tensor=input_tensor, targets=target_layers)[0,:]
    visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)
# Out:
# (192, 160)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[121], line 19
#      17 rgb_img = np.float32(image) / 255
#      18 print(rgb_img.shape)
# ---> 19 input_tensor = preprocess_image(
#      20                                 rgb_img,
#      21                                 mean=[0.485, 0.456, 0.406],
#      22                                 std=[0.229, 0.224, 0.225]
#      23                                 )
#      24 # Construct the CAM object once, and then re-use it on many images:
#      25 with GradCAM(model=model,
#      26              target_layers=target_layers,
#      27              use_cuda=torch.cuda.is_available()) as cam:
#
# File ~/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/pytorch_grad_cam/utils/image.py:20, in preprocess_image(img, mean, std)
#      12 def preprocess_image(
#      13     img: np.ndarray, mean=[
#      14         0.5, 0.5, 0.5], std=[
#      15             0.5, 0.5, 0.5]) -> torch.Tensor:
#      16     preprocessing = Compose([
#      17         ToTensor(),
#      18         Normalize(mean=mean, std=std)
#      19     ])
# ---> 20     return preprocessing(img.copy()).unsqueeze(0)
#
# File ~/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/torchvision/transforms/transforms.py:61, in Compose.__call__(self, img)
#      59 def __call__(self, img):
#      60     for t in self.transforms:
# ---> 61         img = t(img)
#      62     return img
#
# File ~/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/torchvision/transforms/transforms.py:226, in Normalize.forward(self, tensor)
#     218 def forward(self, tensor: Tensor) -> Tensor:
#     219     """
#     220     Args:
#     221         tensor (Tensor): Tensor image to be normalized.
#    (...)
#     224         Tensor: Normalized Tensor image.
#     225     """
# --> 226     return F.normalize(tensor, self.mean, self.std, self.inplace)
#
# File ~/miniconda3/envs/open-mmlab/lib/python3.8/site-packages/torchvision/transforms/functional.py:351, in normalize(tensor, mean, std, inplace)
#     349 if std.ndim == 1:
#     350     std = std.view(-1, 1, 1)
# --> 351 tensor.sub_(mean).div_(std)
#     352 return tensor
#
# RuntimeError: output with shape [1, 192, 160] doesn't match the broadcast shape [3, 192, 160]

# %%
# !python tools/visualization/vis_cam.py \
    data/YoriDataset_vgg/train/MCI/100x-103.png \
    configs/resnet/resnet18_alzheimer_axial_view.py \
    work_dirs/alzheimer/axial/resnet18/epoch_100.pth \
    # --target-layers backbone.layer4.1 \
    --target-layers backbone.layer4.1.bn2 \
    --method GradCAM
    # GradCAM++, XGradCAM, EigenCAM, EigenGradCAM, LayerCAM
# Out:
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 20
# Automatically choose the last norm layer "backbone.layer4.1.bn2" as the target layer.

# %%
import os
import subprocess
train_AD = 'data/YoriDataset_vgg/train/AD'
train_MCI = 'data/YoriDataset_vgg/train/MCI'
train_NC = 'data/YoriDataset_vgg/train/NC'

val_AD = 'data/YoriDataset_vgg/validation/AD'
val_MCI = 'data/YoriDataset_vgg/validation/MCI'
val_NC = 'data/YoriDataset_vgg/validation/NC'

test_AD = 'data/YoriDataset_vgg/test/AD'
test_MCI = 'data/YoriDataset_vgg/test/MCI'
test_NC = 'data/YoriDataset_vgg/test/NC'


trainheat_AD = 'data/resnet_heat/train/AD'
trainheat_MCI = 'data/resnet_heat/train/MCI'
trainheat_NC = 'data/resnet_heat/train/NC'

valheat_AD = 'data/resnet_heat/validation/AD'
valheat_MCI = 'data/resnet_heat/validation/MCI'
valheat_NC = 'data/resnet_heat/validation/NC'

testheat_AD = 'data/vgg_heat/test/AD'
testheat_MCI = 'data/vgg_heat/test/MCI'
testheat_NC = 'data/vgg_heat/test/NC'

count = 0
for i in os.listdir(train_NC):
    count+=1
    temp = os.path.join(train_NC,i)
    out = trainheat_NC + '/heat_'+i
    print(out)  
    subprocess.run(["python", "tools/visualization/vis_cam.py", 
                temp,
                 "configs/resnet/resnet18_alzheimer_axial_view.py",
                 "work_dirs/alzheimer/axial/resnet18/epoch_100.pth",
                 "--target-layers", "backbone.layer4.1.bn2",
                 "--method", "GradCAM++",
                 "--save-path", out,
                 # "--eigen-smooth", "--aug-smooth"
                 ], text=True)
    print(count)
    # break
# Out:
# data/resnet_heat/train/NC/heat_63x-122.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 1
# data/resnet_heat/train/NC/heat_26x-110.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 2
# data/resnet_heat/train/NC/heat_72x-135.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 3
# data/resnet_heat/train/NC/heat_14x-112.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 4
# data/resnet_heat/train/NC/heat_7x-142.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 5
# data/resnet_heat/train/NC/heat_37x-156.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 6
# data/resnet_heat/train/NC/heat_25x-100.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 7
# data/resnet_heat/train/NC/heat_3x-143.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 8
# data/resnet_heat/train/NC/heat_68x-122.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 9
# data/resnet_heat/train/NC/heat_55x-134.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 10
# data/resnet_heat/train/NC/heat_62x-137.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 11
# data/resnet_heat/train/NC/heat_45x-114.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 12
# data/resnet_heat/train/NC/heat_66x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 13
# data/resnet_heat/train/NC/heat_97x-100.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 14
# data/resnet_heat/train/NC/heat_68x-116.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 15
# data/resnet_heat/train/NC/heat_8x-116.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 16
# data/resnet_heat/train/NC/heat_46x-140.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 17
# data/resnet_heat/train/NC/heat_41x-134.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 18
# data/resnet_heat/train/NC/heat_4x-123.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 19
# data/resnet_heat/train/NC/heat_91x-99.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 20
# data/resnet_heat/train/NC/heat_21x-89.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 21
# data/resnet_heat/train/NC/heat_84x-123.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 22
# data/resnet_heat/train/NC/heat_45x-116.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 23
# data/resnet_heat/train/NC/heat_93x-102.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 24
# data/resnet_heat/train/NC/heat_98x-108.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 25
# data/resnet_heat/train/NC/heat_68x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 26
# data/resnet_heat/train/NC/heat_58x-151.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 27
# data/resnet_heat/train/NC/heat_84x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 28
# data/resnet_heat/train/NC/heat_6x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 29
# data/resnet_heat/train/NC/heat_61x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 30
# data/resnet_heat/train/NC/heat_45x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 31
# data/resnet_heat/train/NC/heat_45x-118.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 32
# data/resnet_heat/train/NC/heat_44x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 33
# data/resnet_heat/train/NC/heat_82x-123.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 34
# data/resnet_heat/train/NC/heat_27x-111.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 35
# data/resnet_heat/train/NC/heat_77x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 36
# data/resnet_heat/train/NC/heat_42x-132.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 37
# data/resnet_heat/train/NC/heat_47x-142.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 38
# data/resnet_heat/train/NC/heat_28x-152.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 39
# data/resnet_heat/train/NC/heat_31x-152.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 40
# data/resnet_heat/train/NC/heat_17x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 41
# data/resnet_heat/train/NC/heat_15x-135.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 42
# data/resnet_heat/train/NC/heat_27x-117.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 43
# data/resnet_heat/train/NC/heat_93x-106.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 44
# data/resnet_heat/train/NC/heat_37x-154.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 45
# data/resnet_heat/train/NC/heat_22x-87.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 46
# data/resnet_heat/train/NC/heat_29x-153.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 47
# data/resnet_heat/train/NC/heat_63x-128.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 48
# data/resnet_heat/train/NC/heat_39x-127.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 49
# data/resnet_heat/train/NC/heat_10x-144.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 50
# data/resnet_heat/train/NC/heat_12x-113.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 51
# data/resnet_heat/train/NC/heat_73x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 52
# data/resnet_heat/train/NC/heat_85x-121.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 53
# data/resnet_heat/train/NC/heat_76x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 54
# data/resnet_heat/train/NC/heat_99x-100.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 55
# data/resnet_heat/train/NC/heat_47x-140.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 56
# data/resnet_heat/train/NC/heat_86x-135.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 57
# data/resnet_heat/train/NC/heat_49x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 58
# data/resnet_heat/train/NC/heat_99x-98.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 59
# data/resnet_heat/train/NC/heat_82x-121.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 60
# data/resnet_heat/train/NC/heat_14x-116.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 61
# data/resnet_heat/train/NC/heat_77x-127.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 62
# data/resnet_heat/train/NC/heat_41x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 63
# data/resnet_heat/train/NC/heat_56x-136.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 64
# data/resnet_heat/train/NC/heat_14x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 65
# data/resnet_heat/train/NC/heat_92x-106.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 66
# data/resnet_heat/train/NC/heat_13x-116.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 67
# data/resnet_heat/train/NC/heat_65x-134.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 68
# data/resnet_heat/train/NC/heat_75x-135.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 69
# data/resnet_heat/train/NC/heat_36x-136.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 70
# data/resnet_heat/train/NC/heat_79x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 71
# data/resnet_heat/train/NC/heat_6x-121.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 72
# data/resnet_heat/train/NC/heat_10x-136.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 73
# data/resnet_heat/train/NC/heat_52x-144.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 74
# data/resnet_heat/train/NC/heat_43x-128.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 75
# data/resnet_heat/train/NC/heat_31x-150.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 76
# data/resnet_heat/train/NC/heat_84x-127.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 77
# data/resnet_heat/train/NC/heat_61x-133.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 78
# data/resnet_heat/train/NC/heat_78x-123.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 79
# data/resnet_heat/train/NC/heat_94x-105.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 80
# data/resnet_heat/train/NC/heat_12x-115.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 81
# data/resnet_heat/train/NC/heat_97x-96.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 82
# data/resnet_heat/train/NC/heat_8x-118.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 83
# data/resnet_heat/train/NC/heat_15x-139.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 84
# data/resnet_heat/train/NC/heat_86x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 85
# data/resnet_heat/train/NC/heat_32x-147.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 86
# data/resnet_heat/train/NC/heat_35x-147.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 87
# data/resnet_heat/train/NC/heat_67x-134.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 88
# data/resnet_heat/train/NC/heat_36x-132.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 89
# data/resnet_heat/train/NC/heat_3x-139.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 90
# data/resnet_heat/train/NC/heat_30x-135.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 91
# data/resnet_heat/train/NC/heat_37x-152.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 92
# data/resnet_heat/train/NC/heat_26x-102.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 93
# data/resnet_heat/train/NC/heat_23x-89.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 94
# data/resnet_heat/train/NC/heat_79x-114.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 95
# data/resnet_heat/train/NC/heat_81x-119.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 96
# data/resnet_heat/train/NC/heat_56x-138.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 97
# data/resnet_heat/train/NC/heat_67x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 98
# data/resnet_heat/train/NC/heat_46x-142.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 99
# data/resnet_heat/train/NC/heat_42x-136.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 100
# data/resnet_heat/train/NC/heat_55x-136.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 101
# data/resnet_heat/train/NC/heat_93x-110.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 102
# data/resnet_heat/train/NC/heat_94x-107.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 103
# data/resnet_heat/train/NC/heat_96x-100.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 104
# data/resnet_heat/train/NC/heat_98x-109.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 105
# data/resnet_heat/train/NC/heat_54x-146.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 106
# data/resnet_heat/train/NC/heat_88x-108.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 107
# data/resnet_heat/train/NC/heat_26x-106.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 108
# data/resnet_heat/train/NC/heat_24x-105.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 109
# data/resnet_heat/train/NC/heat_17x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 110
# data/resnet_heat/train/NC/heat_77x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 111
# data/resnet_heat/train/NC/heat_70x-137.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 112
# data/resnet_heat/train/NC/heat_98x-105.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 113
# data/resnet_heat/train/NC/heat_57x-145.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 114
# data/resnet_heat/train/NC/heat_71x-135.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 115
# data/resnet_heat/train/NC/heat_29x-157.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 116
# data/resnet_heat/train/NC/heat_1x-122.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 117
# data/resnet_heat/train/NC/heat_69x-128.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 118
# data/resnet_heat/train/NC/heat_74x-137.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 119
# data/resnet_heat/train/NC/heat_52x-138.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 120
# data/resnet_heat/train/NC/heat_39x-133.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 121
# data/resnet_heat/train/NC/heat_63x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 122
# data/resnet_heat/train/NC/heat_56x-132.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 123
# data/resnet_heat/train/NC/heat_23x-93.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 124
# data/resnet_heat/train/NC/heat_41x-132.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 125
# data/resnet_heat/train/NC/heat_92x-104.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 126
# data/resnet_heat/train/NC/heat_9x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 127
# data/resnet_heat/train/NC/heat_17x-128.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 128
# data/resnet_heat/train/NC/heat_17x-124.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 129
# data/resnet_heat/train/NC/heat_55x-130.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 130
# data/resnet_heat/train/NC/heat_72x-133.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 131
# data/resnet_heat/train/NC/heat_58x-145.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 132
# data/resnet_heat/train/NC/heat_72x-141.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 133
# data/resnet_heat/train/NC/heat_13x-118.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 134
# data/resnet_heat/train/NC/heat_43x-132.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 135
# data/resnet_heat/train/NC/heat_26x-104.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 136
# data/resnet_heat/train/NC/heat_50x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 137
# data/resnet_heat/train/NC/heat_99x-96.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 138
# data/resnet_heat/train/NC/heat_82x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 139
# data/resnet_heat/train/NC/heat_68x-124.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 140
# data/resnet_heat/train/NC/heat_21x-87.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 141
# data/resnet_heat/train/NC/heat_74x-133.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 142
# data/resnet_heat/train/NC/heat_40x-132.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 143
# data/resnet_heat/train/NC/heat_57x-141.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 144
# data/resnet_heat/train/NC/heat_51x-142.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 145
# data/resnet_heat/train/NC/heat_88x-110.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 146
# data/resnet_heat/train/NC/heat_91x-95.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 147
# data/resnet_heat/train/NC/heat_59x-128.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 148
# data/resnet_heat/train/NC/heat_73x-121.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 149
# data/resnet_heat/train/NC/heat_91x-97.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 150
# data/resnet_heat/train/NC/heat_94x-109.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 151
# data/resnet_heat/train/NC/heat_81x-117.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 152
# data/resnet_heat/train/NC/heat_79x-122.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 153
# data/resnet_heat/train/NC/heat_85x-127.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 154
# data/resnet_heat/train/NC/heat_87x-115.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 155
# data/resnet_heat/train/NC/heat_7x-144.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 156
# data/resnet_heat/train/NC/heat_96x-97.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 157
# data/resnet_heat/train/NC/heat_9x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 158
# data/resnet_heat/train/NC/heat_5x-133.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 159
# data/resnet_heat/train/NC/heat_35x-143.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 160
# data/resnet_heat/train/NC/heat_69x-122.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 161
# data/resnet_heat/train/NC/heat_5x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 162
# data/resnet_heat/train/NC/heat_4x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 163
# data/resnet_heat/train/NC/heat_89x-97.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 164
# data/resnet_heat/train/NC/heat_49x-133.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 165
# data/resnet_heat/train/NC/heat_60x-137.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 166
# data/resnet_heat/train/NC/heat_84x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 167
# data/resnet_heat/train/NC/heat_58x-147.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 168
# data/resnet_heat/train/NC/heat_18x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 169
# data/resnet_heat/train/NC/heat_3x-145.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 170
# data/resnet_heat/train/NC/heat_2x-141.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 171
# data/resnet_heat/train/NC/heat_95x-102.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 172
# data/resnet_heat/train/NC/heat_66x-128.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 173
# data/resnet_heat/train/NC/heat_89x-99.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 174
# data/resnet_heat/train/NC/heat_18x-122.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 175
# data/resnet_heat/train/NC/heat_53x-127.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 176
# data/resnet_heat/train/NC/heat_9x-124.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 177
# data/resnet_heat/train/NC/heat_71x-137.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 178
# data/resnet_heat/train/NC/heat_33x-121.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 179
# data/resnet_heat/train/NC/heat_95x-101.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 180
# data/resnet_heat/train/NC/heat_60x-139.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 181
# data/resnet_heat/train/NC/heat_34x-145.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 182
# data/resnet_heat/train/NC/heat_54x-142.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 183
# data/resnet_heat/train/NC/heat_78x-127.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 184
# data/resnet_heat/train/NC/heat_51x-146.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 185
# data/resnet_heat/train/NC/heat_7x-138.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 186
# data/resnet_heat/train/NC/heat_60x-135.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 187
# data/resnet_heat/train/NC/heat_99x-99.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 188
# data/resnet_heat/train/NC/heat_58x-149.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 189
# data/resnet_heat/train/NC/heat_34x-153.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 190
# data/resnet_heat/train/NC/heat_46x-138.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 191
# data/resnet_heat/train/NC/heat_100x-105.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 192
# data/resnet_heat/train/NC/heat_58x-143.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 193
# data/resnet_heat/train/NC/heat_83x-122.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 194
# data/resnet_heat/train/NC/heat_50x-130.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 195
# data/resnet_heat/train/NC/heat_70x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 196
# data/resnet_heat/train/NC/heat_25x-104.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 197
# data/resnet_heat/train/NC/heat_30x-139.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 198
# data/resnet_heat/train/NC/heat_38x-157.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 199
# data/resnet_heat/train/NC/heat_74x-135.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 200
# data/resnet_heat/train/NC/heat_57x-147.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 201
# data/resnet_heat/train/NC/heat_65x-136.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 202
# data/resnet_heat/train/NC/heat_75x-133.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 203
# data/resnet_heat/train/NC/heat_56x-130.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 204
# data/resnet_heat/train/NC/heat_10x-140.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 205
# data/resnet_heat/train/NC/heat_57x-143.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 206
# data/resnet_heat/train/NC/heat_87x-121.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 207
# data/resnet_heat/train/NC/heat_87x-117.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 208
# data/resnet_heat/train/NC/heat_81x-123.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 209
# data/resnet_heat/train/NC/heat_24x-109.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 210
# data/resnet_heat/train/NC/heat_18x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 211
# data/resnet_heat/train/NC/heat_19x-123.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 212
# data/resnet_heat/train/NC/heat_80x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 213
# data/resnet_heat/train/NC/heat_90x-103.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 214
# data/resnet_heat/train/NC/heat_71x-139.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 215
# data/resnet_heat/train/NC/heat_14x-114.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 216
# data/resnet_heat/train/NC/heat_55x-138.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 217
# data/resnet_heat/train/NC/heat_31x-148.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 218
# data/resnet_heat/train/NC/heat_17x-122.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 219
# data/resnet_heat/train/NC/heat_49x-137.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 220
# data/resnet_heat/train/NC/heat_96x-98.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 221
# data/resnet_heat/train/NC/heat_42x-140.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 222
# data/resnet_heat/train/NC/heat_83x-118.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 223
# data/resnet_heat/train/NC/heat_100x-102.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 224
# data/resnet_heat/train/NC/heat_73x-119.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 225
# data/resnet_heat/train/NC/heat_88x-114.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 226
# data/resnet_heat/train/NC/heat_76x-118.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 227
# data/resnet_heat/train/NC/heat_69x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 228
# data/resnet_heat/train/NC/heat_12x-117.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 229
# data/resnet_heat/train/NC/heat_22x-85.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 230
# data/resnet_heat/train/NC/heat_72x-139.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 231
# data/resnet_heat/train/NC/heat_99x-97.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 232
# data/resnet_heat/train/NC/heat_89x-95.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 233
# data/resnet_heat/train/NC/heat_65x-130.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 234
# data/resnet_heat/train/NC/heat_87x-113.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 235
# data/resnet_heat/train/NC/heat_27x-113.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 236
# data/resnet_heat/train/NC/heat_33x-119.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 237
# data/resnet_heat/train/NC/heat_47x-136.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 238
# data/resnet_heat/train/NC/heat_71x-141.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 239
# data/resnet_heat/train/NC/heat_90x-101.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 240
# data/resnet_heat/train/NC/heat_28x-156.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 241
# data/resnet_heat/train/NC/heat_44x-118.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 242
# data/resnet_heat/train/NC/heat_23x-97.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 243
# data/resnet_heat/train/NC/heat_63x-124.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 244
# data/resnet_heat/train/NC/heat_38x-161.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 245
# data/resnet_heat/train/NC/heat_25x-106.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 246
# data/resnet_heat/train/NC/heat_83x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 247
# data/resnet_heat/train/NC/heat_52x-142.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 248
# data/resnet_heat/train/NC/heat_53x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 249
# data/resnet_heat/train/NC/heat_43x-134.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 250
# data/resnet_heat/train/NC/heat_98x-107.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 251
# data/resnet_heat/train/NC/heat_85x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 252
# data/resnet_heat/train/NC/heat_86x-137.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 253
# data/resnet_heat/train/NC/heat_50x-128.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 254
# data/resnet_heat/train/NC/heat_52x-140.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 255
# data/resnet_heat/train/NC/heat_66x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 256
# data/resnet_heat/train/NC/heat_40x-134.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 257
# data/resnet_heat/train/NC/heat_96x-99.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 258
# data/resnet_heat/train/NC/heat_70x-133.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 259
# data/resnet_heat/train/NC/heat_80x-127.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 260
# data/resnet_heat/train/NC/heat_69x-124.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 261
# data/resnet_heat/train/NC/heat_51x-138.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 262
# data/resnet_heat/train/NC/heat_90x-99.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 263
# data/resnet_heat/train/NC/heat_13x-112.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 264
# data/resnet_heat/train/NC/heat_51x-140.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 265
# data/resnet_heat/train/NC/heat_78x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 266
# data/resnet_heat/train/NC/heat_81x-115.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 267
# data/resnet_heat/train/NC/heat_92x-108.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 268
# data/resnet_heat/train/NC/heat_51x-144.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 269
# data/resnet_heat/train/NC/heat_62x-139.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 270
# data/resnet_heat/train/NC/heat_80x-123.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 271
# data/resnet_heat/train/NC/heat_55x-132.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 272
# data/resnet_heat/train/NC/heat_76x-124.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 273
# data/resnet_heat/train/NC/heat_31x-146.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 274
# data/resnet_heat/train/NC/heat_84x-121.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 275
# data/resnet_heat/train/NC/heat_66x-124.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 276
# data/resnet_heat/train/NC/heat_70x-135.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 277
# data/resnet_heat/train/NC/heat_4x-121.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 278
# data/resnet_heat/train/NC/heat_21x-85.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 279
# data/resnet_heat/train/NC/heat_69x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 280
# data/resnet_heat/train/NC/heat_28x-160.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 281
# data/resnet_heat/train/NC/heat_34x-149.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 282
# data/resnet_heat/train/NC/heat_83x-124.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 283
# data/resnet_heat/train/NC/heat_44x-124.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 284
# data/resnet_heat/train/NC/heat_91x-93.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 285
# data/resnet_heat/train/NC/heat_90x-105.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 286
# data/resnet_heat/train/NC/heat_45x-122.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 287
# data/resnet_heat/train/NC/heat_24x-101.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 288
# data/resnet_heat/train/NC/heat_79x-116.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 289
# data/resnet_heat/train/NC/heat_16x-113.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 290
# data/resnet_heat/train/NC/heat_67x-130.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 291
# data/resnet_heat/train/NC/heat_32x-153.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 292
# data/resnet_heat/train/NC/heat_60x-133.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 293
# data/resnet_heat/train/NC/heat_2x-145.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 294
# data/resnet_heat/train/NC/heat_66x-122.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 295
# data/resnet_heat/train/NC/heat_64x-138.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 296
# data/resnet_heat/train/NC/heat_74x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 297
# data/resnet_heat/train/NC/heat_12x-111.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 298
# data/resnet_heat/train/NC/heat_75x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 299
# data/resnet_heat/train/NC/heat_3x-137.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 300
# data/resnet_heat/train/NC/heat_39x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 301
# data/resnet_heat/train/NC/heat_16x-121.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 302
# data/resnet_heat/train/NC/heat_64x-136.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 303
# data/resnet_heat/train/NC/heat_97x-97.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 304
# data/resnet_heat/train/NC/heat_27x-119.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 305
# data/resnet_heat/train/NC/heat_27x-115.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 306
# data/resnet_heat/train/NC/heat_49x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 307
# data/resnet_heat/train/NC/heat_22x-91.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 308
# data/resnet_heat/train/NC/heat_64x-130.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 309
# data/resnet_heat/train/NC/heat_47x-144.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 310
# data/resnet_heat/train/NC/heat_20x-127.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 311
# data/resnet_heat/train/NC/heat_61x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 312
# data/resnet_heat/train/NC/heat_19x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 313
# data/resnet_heat/train/NC/heat_100x-106.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 314
# data/resnet_heat/train/NC/heat_62x-143.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 315
# data/resnet_heat/train/NC/heat_21x-91.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 316
# data/resnet_heat/train/NC/heat_20x-119.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 317
# data/resnet_heat/train/NC/heat_6x-117.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 318
# data/resnet_heat/train/NC/heat_97x-99.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 319
# data/resnet_heat/train/NC/heat_94x-103.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 320
# data/resnet_heat/train/NC/heat_32x-145.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 321
# data/resnet_heat/train/NC/heat_64x-134.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 322
# data/resnet_heat/train/NC/heat_86x-133.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 323
# data/resnet_heat/train/NC/heat_8x-124.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 324
# data/resnet_heat/train/NC/heat_52x-146.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 325
# data/resnet_heat/train/NC/heat_80x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 326
# data/resnet_heat/train/NC/heat_61x-127.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 327
# data/resnet_heat/train/NC/heat_41x-128.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 328
# data/resnet_heat/train/NC/heat_33x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 329
# data/resnet_heat/train/NC/heat_36x-134.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 330
# data/resnet_heat/train/NC/heat_85x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 331
# data/resnet_heat/train/NC/heat_87x-119.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 332
# data/resnet_heat/train/NC/heat_95x-99.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 333
# data/resnet_heat/train/NC/heat_100x-104.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 334
# data/resnet_heat/train/NC/heat_53x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 335
# data/resnet_heat/train/NC/heat_40x-136.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 336
# data/resnet_heat/train/NC/heat_100x-103.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 337
# data/resnet_heat/train/NC/heat_36x-128.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 338
# data/resnet_heat/train/NC/heat_22x-93.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 339
# data/resnet_heat/train/NC/heat_95x-98.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 340
# data/resnet_heat/train/NC/heat_83x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 341
# data/resnet_heat/train/NC/heat_67x-132.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 342
# data/resnet_heat/train/NC/heat_30x-137.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 343
# data/resnet_heat/train/NC/heat_93x-108.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 344
# data/resnet_heat/train/NC/heat_5x-135.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 345
# data/resnet_heat/train/NC/heat_42x-134.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 346
# data/resnet_heat/train/NC/heat_97x-98.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 347
# data/resnet_heat/train/NC/heat_48x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 348
# data/resnet_heat/train/NC/heat_65x-138.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 349
# data/resnet_heat/train/NC/heat_20x-123.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 350
# data/resnet_heat/train/NC/heat_73x-117.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 351
# data/resnet_heat/train/NC/heat_56x-134.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 352
# data/resnet_heat/train/NC/heat_78x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 353
# data/resnet_heat/train/NC/heat_46x-136.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 354
# data/resnet_heat/train/NC/heat_47x-138.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 355
# data/resnet_heat/train/NC/heat_48x-137.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 356
# data/resnet_heat/train/NC/heat_82x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 357
# data/resnet_heat/train/NC/heat_38x-153.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 358
# data/resnet_heat/train/NC/heat_62x-141.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 359
# data/resnet_heat/train/NC/heat_12x-119.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 360
# data/resnet_heat/train/NC/heat_44x-116.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 361
# data/resnet_heat/train/NC/heat_62x-135.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 362
# data/resnet_heat/train/NC/heat_14x-118.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 363
# data/resnet_heat/train/NC/heat_93x-104.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 364
# data/resnet_heat/train/NC/heat_30x-131.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 365
# data/resnet_heat/train/NC/heat_16x-117.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 366
# data/resnet_heat/train/NC/heat_18x-124.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 367
# data/resnet_heat/train/NC/heat_54x-140.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 368
# data/resnet_heat/train/NC/heat_1x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 369
# data/resnet_heat/train/NC/heat_23x-95.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 370
# data/resnet_heat/train/NC/heat_19x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 371
# data/resnet_heat/train/NC/heat_8x-122.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 372
# data/resnet_heat/train/NC/heat_53x-125.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 373
# data/resnet_heat/train/NC/heat_59x-126.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 374
# data/resnet_heat/train/NC/heat_59x-130.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 375
# data/resnet_heat/train/NC/heat_32x-149.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 376
# data/resnet_heat/train/NC/heat_88x-106.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 377
# data/resnet_heat/train/NC/heat_11x-113.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 378
# data/resnet_heat/train/NC/heat_48x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 379
# data/resnet_heat/train/NC/heat_54x-144.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 380
# data/resnet_heat/train/NC/heat_65x-132.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 381
# data/resnet_heat/train/NC/heat_37x-150.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 382
# data/resnet_heat/train/NC/heat_74x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 383
# data/resnet_heat/train/NC/heat_4x-127.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 384
# data/resnet_heat/train/NC/heat_75x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 385
# data/resnet_heat/train/NC/heat_35x-149.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 386
# data/resnet_heat/train/NC/heat_77x-123.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 387
# data/resnet_heat/train/NC/heat_2x-137.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 388
# data/resnet_heat/train/NC/heat_90x-97.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 389
# data/resnet_heat/train/NC/heat_40x-130.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 390
# data/resnet_heat/train/NC/heat_80x-121.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 391
# data/resnet_heat/train/NC/heat_36x-130.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 392
# data/resnet_heat/train/NC/heat_48x-133.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 393
# data/resnet_heat/train/NC/heat_96x-96.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 394
# data/resnet_heat/train/NC/heat_88x-112.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 395
# data/resnet_heat/train/NC/heat_5x-129.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 396
# data/resnet_heat/train/NC/heat_11x-117.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 397
# data/resnet_heat/train/NC/heat_13x-120.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 398
# data/resnet_heat/train/NC/heat_92x-102.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 399
# data/resnet_heat/train/NC/heat_59x-132.png
# Loads checkpoint by local backend from path: work_dirs/alzheimer/axial/resnet18/epoch_100.pth
# 400
